# %% [markdown]
# <h1>ML_Pattern_Classification project | Main File</h1>

# %%
#import BirdsData from BirdExplore
from BirdExplore import BirdsData
import os
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.decomposition import PCA, KernelPCA
import matplotlib.pyplot as plt
from matplotlib import cm

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[1], line 2
#       1 #import BirdsData from BirdExplore
# ----> 2 from BirdExplore import BirdsData
#       3 import os
#       4 import seaborn as sns
#
# File ~/Desktop/JKU/Semester 4/ML Pattern Classification/BirdExplore.py:290
#     283         return np.array(labels_ar_list)
#     289 bird = BirdsData('ptichki')
# --> 290 print(bird.cor_feat_label())
#     292 a = [1,0,0,0,0]
#     293 b = [1,1,1,0]
#
# File ~/Desktop/JKU/Semester 4/ML Pattern Classification/BirdExplore.py:258, in BirdsData.cor_feat_label(self)
#     256 def cor_feat_label(self):
#     257     c = BirdsData('ptichki')
# --> 258     X = c.united_dataset()[:, 0:548]
#     259     y = c.united_dataset()[:, -1]
#     260     cors = [np.corrcoef(x=X[:, i], y=y)[1, 0] for i in range(548)]
#
# File ~/Desktop/JKU/Semester 4/ML Pattern Classification/BirdExplore.py:44, in BirdsData.united_dataset(self)
#      40 def united_dataset(self):
#      42     birds = [os.path.join(self.project_folder, b)
#      43              for b in os.listdir(self.project_folder)]
# ---> 44     all_files = [os.path.join(bird, f)
#      45                  for bird in birds for f in os.listdir(bird)]
#      46     all_files = sorted([f for f in all_files if not 'labels' in f])
#      48     comcuc = [f for f in all_files if 'comcuc' in f]
#
# File ~/Desktop/JKU/Semester 4/ML Pattern Classification/BirdExplore.py:45, in <listcomp>(.0)
#      40 def united_dataset(self):
#      42     birds = [os.path.join(self.project_folder, b)
#      43              for b in os.listdir(self.project_folder)]
#      44     all_files = [os.path.join(bird, f)
# ---> 45                  for bird in birds for f in os.listdir(bird)]
#      46     all_files = sorted([f for f in all_files if not 'labels' in f])
#      48     comcuc = [f for f in all_files if 'comcuc' in f]
#
# NotADirectoryError: [Errno 20] Not a directory: 'ptichki/.DS_Store'

# %%
BirdsData('bird_data').labels_distribution()

# %%
def get_sound_label(species, sample,project_folder):
    folder_path = os.path.join(project_folder, species)
    file_list = os.listdir(folder_path)
    for file in file_list:
        if file.endswith('.npy'):
            file_path = os.path.join(folder_path, sample)
            data = np.load(f'{file_path}.npy')
            label = np.load(f'{file_path}.labels.npy')
            return data

data = get_sound_label('comcuc','25627','ptichki')

# %% [markdown]
# <h3>Load dataset</h3>

# %%
united_data = BirdsData('ptichki').united_dataset()
print(united_data.shape)

# %%
# df = pd.DataFrame(united_data,columns=)
full_df = BirdsData('ptichki').get_dataframe()

# %% [markdown]
# <h4>Create correlation histogram between labels by choosing threshold to improve readability. Needs to be fixed</h4>

# %%
corr = full_df.corr()
threshold = 0.9
filtered_corr = corr[(corr >= threshold) & (corr != 1.000)]
f, ax = plt.subplots(figsize=(12, 10))
mask = np.triu(np.ones_like(filtered_corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(filtered_corr, annot=True, mask = mask, cmap='Reds')

# %% [markdown]
# <h4>Plotting MFCC for each bird species</h4>
# <li>We can plot any features by chosing feature name</li>

# %%
def Plot_MFCC(data,target,cols,title='',plot_type='imshow'):
    filtered_data = data.loc[data['target'] == target]
    data = filtered_data[filtered_data.columns[cols]]
    plt.figure(figsize=(30, 20))
    #plt.subplot(3,1,1)
    if plot_type == 'imshow': 
        plt.imshow(data.T,cmap=plt.cm.jet, aspect='auto',origin='lower')
    elif plot_type == 'scatter':
        print(f'Mean value of {title} for {target} : {data.mean()}')
        plt.plot(np.squeeze(data))
    plt.ylabel('MFCC')
    plt.xlabel('Samples')
    plt.title(title)

def find_idx_by_string(data:list,string):
    res = []
    for idx,elem in enumerate(data):
        if string in elem:
            res.append(idx)
    return res

# Plot_MFCC(full_df,'comcuc',find_idx_by_string(list(full_df.columns),'mfcc_mean'),'Comcuc MFCC')
# Plot_MFCC(full_df,'cowpig1',find_idx_by_string(list(full_df.columns),'mfcc_mean'),'Cowpig MFCC')
# Plot_MFCC(full_df,'eucdov',find_idx_by_string(list(full_df.columns),'mfcc_mean'),'Eucdow MFCC')
# Plot_MFCC(full_df,'grswoo',find_idx_by_string(list(full_df.columns),'mfcc_mean'),'Grswoo MFCC')

# %% [markdown]
# <h3>Plotting call/drumming duration for each species</h3>

# %%
BirdsData('ptichki').species_call_distribution()

# %% [markdown]
# <h3>Use RandomForest to find most important features</h3>

# %%
data = full_df.drop('target',axis=1)
labels = full_df.loc[:, 'target']
print(data.shape)
print(labels.shape)

X_train, X_test, y_train, y_test = train_test_split(data, labels, random_state=42)

rf = RandomForestClassifier()
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# (120000, 548)
# (120000,)
# array([0.00371898, 0.00120482, 0.00210306, 0.00201807, 0.00324717,
#        0.00306815, 0.00353574, 0.00302375, 0.00399355, 0.00355718,
#        0.0027093 , 0.00288464, 0.00261399, 0.00217342, 0.00233247,
#        0.00175046, 0.00191109, 0.0018934 , 0.00211492, 0.0025835 ,
#        0.0060372 , 0.00997319, 0.01343542, 0.01202577, 0.00484853,
#        0.00367621, 0.0026882 , 0.00221233, 0.00220052, 0.00300767,
#        0.00243372, 0.00203347, 0.00203657, 0.00186844, 0.00172928,
#        0.00158603, 0.00194717, 0.00217785, 0.00221891, 0.00212051,
#        0.0017014 , 0.00120308, 0.00111181, 0.00102773, 0.00100923,
#        0.00111953, 0.0011414 , 0.00101564, 0.00112163, 0.00132798,
#        0.00099188, 0.00103148, 0.00100892, 0.00102337, 0.00095956,
#        0.00091507, 0.00095598, 0.00100077, 0.00099435, 0.0010378 ,
#        0.00109225, 0.00119226, 0.00128556, 0.00091401, 0.001006  ,
#        0.00110357, 0.00097557, 0.00120158, 0.00102129, 0.00114447,
#        0.00133729, 0.00119945, 0.00147966, 0.00155297, 0.00167627,
#        0.0017977 , 0.00077311, 0.00072188, 0.0008227 , 0.00197591,
#        0.00288517, 0.00635552, 0.01067147, 0.00884456, 0.00764269,
#        0.00537798, 0.0014481 , 0.00127593, 0.00095966, 0.00094132,
#        0.00086425, 0.00088942, 0.00087179, 0.00098059, 0.00090004,
#        0.00089944, 0.00082255, 0.00077898, 0.00078717, 0.00073901,
#        0.00086158, 0.00079928, 0.00061572, 0.00067489, 0.00098087,
#        0.00103192, 0.00123709, 0.00193076, 0.00133611, 0.00202303,
#        0.00079497, 0.00069856, 0.00067284, 0.00066931, 0.00093793,
#        0.00070345, 0.00065901, 0.00079333, 0.00087131, 0.00101736,
#        0.00094695, 0.00114163, 0.00148995, 0.00113403, 0.00065337,
#        0.00063443, 0.00087037, 0.0006917 , 0.0007442 , 0.00062833,
#        0.00074161, 0.00068048, 0.00078932, 0.00078493, 0.00081837,
#        0.00089325, 0.00127457, 0.00229467, 0.00206366, 0.00263666,
#        0.00114897, 0.00143661, 0.00187193, 0.0040884 , 0.00636234,
#        0.00425485, 0.00498887, 0.00221304, 0.00469061, 0.0041594 ,
#        0.00402985, 0.00389869, 0.00416261, 0.00329709, 0.00292189,
#        0.00194426, 0.00500948, 0.00384657, 0.00093618, 0.00073804,
#        0.00072155, 0.00075322, 0.00083673, 0.00093384, 0.00082159,
#        0.0012404 , 0.00073236, 0.00079454, 0.00096903, 0.00091661,
#        0.00102351, 0.00115676, 0.00078018, 0.00083911, 0.00130825,
#        0.00127221, 0.00209545, 0.00164013, 0.00090203, 0.00088695,
#        0.00064425, 0.00063197, 0.00063063, 0.00069066, 0.00072511,
#        0.0008378 , 0.00076312, 0.00084736, 0.00071259, 0.00062933,
#        0.0008027 , 0.00079584, 0.00079408, 0.00082095, 0.00087554,
#        0.00081798, 0.00450641, 0.003129  , 0.00090847, 0.00067034,
#        0.000748  , 0.00067353, 0.00072535, 0.00079438, 0.00081371,
#        0.00075746, 0.0007533 , 0.00071024, 0.00080933, 0.00087367,
#        0.00077272, 0.00082805, 0.00064801, 0.00072176, 0.00133525,
#        0.00116689, 0.00116721, 0.00113017, 0.00080681, 0.00060309,
#        0.00060067, 0.00065319, 0.00068411, 0.00077595, 0.00078383,
#        0.00074159, 0.00068043, 0.00070646, 0.00071755, 0.00084321,
#        0.00073443, 0.00076231, 0.00067241, 0.00066877, 0.00065423,
#        0.00062448, 0.00391942, 0.00184363, 0.0011468 , 0.0006966 ,
#        0.00084857, 0.00065978, 0.00073097, 0.00074577, 0.00068423,
#        0.00062766, 0.00073662, 0.00062156, 0.00066038, 0.00065438,
#        0.00064819, 0.0006193 , 0.00067346, 0.00074295, 0.00100652,
#        0.00101318, 0.00194447, 0.00150325, 0.00142729, 0.00082241,
#        0.00363829, 0.00444351, 0.00162867, 0.00520717, 0.00512342,
#        0.00583433, 0.00119009, 0.00092681, 0.0015383 , 0.00091617,
#        0.00316327, 0.02823263, 0.00561462, 0.00139535, 0.0016988 ,
#        0.000663  , 0.00061188, 0.00086964, 0.00519791, 0.00070578,
#        0.00069413, 0.00079994, 0.0007921 , 0.00076641, 0.00099815,
#        0.00335537, 0.00926525, 0.01551226, 0.01730955, 0.02041515,
#        0.01043508, 0.01128843, 0.00604239, 0.00394954, 0.00324801,
#        0.00307913, 0.00263993, 0.00200896, 0.00141429, 0.00128926,
#        0.00130368, 0.00140249, 0.00131744, 0.0012908 , 0.00103406,
#        0.00140193, 0.00125142, 0.00098229, 0.0009021 , 0.00080812,
#        0.00086805, 0.00088049, 0.00099588, 0.00089698, 0.00153453,
#        0.00126445, 0.00132855, 0.00193537, 0.00157618, 0.00171004,
#        0.00133973, 0.00105546, 0.00089152, 0.00078625, 0.00074721,
#        0.00076885, 0.00087186, 0.00103274, 0.0007849 , 0.00079809,
#        0.00069791, 0.00071329, 0.00074311, 0.0006484 , 0.00060092,
#        0.00065517, 0.00065269, 0.0006316 , 0.00064532, 0.00062414,
#        0.00066091, 0.00064586, 0.00079989, 0.00073482, 0.00083759,
#        0.00173384, 0.00328615, 0.00363123, 0.00646304, 0.01122547,
#        0.00455472, 0.00335445, 0.00114157, 0.00112428, 0.00114342,
#        0.00087589, 0.00080642, 0.00097614, 0.00081559, 0.00100665,
#        0.00098915, 0.00095222, 0.000849  , 0.00072299, 0.00075669,
#        0.00082536, 0.0007022 , 0.00076812, 0.00069773, 0.00071992,
#        0.0007827 , 0.00112146, 0.00158372, 0.00195788, 0.00143173,
#        0.00095565, 0.00078593, 0.00092536, 0.00078712, 0.00082779,
#        0.00062583, 0.0007296 , 0.00071935, 0.00074666, 0.0007971 ,
#        0.00095625, 0.00135305, 0.00110272, 0.00103238, 0.00107023,
#        0.00069824, 0.00067754, 0.0008811 , 0.00061921, 0.00079847,
#        0.00072086, 0.00071162, 0.00069116, 0.0007173 , 0.00077286,
#        0.00068366, 0.00086016, 0.0073367 , 0.00445442, 0.00160336,
#        0.00106575, 0.00116775, 0.00165545, 0.00149897, 0.00669732,
#        0.00401236, 0.00581483, 0.00312227, 0.00153907, 0.00165159,
#        0.00160391, 0.00249818, 0.00223929, 0.00208216, 0.00178842,
#        0.00136168, 0.00129068, 0.00440279, 0.00312806, 0.00078645,
#        0.00067325, 0.00082294, 0.0007543 , 0.00075545, 0.00085848,
#        0.00078012, 0.00091832, 0.00068924, 0.00071795, 0.0010854 ,
#        0.00092949, 0.00075231, 0.00070035, 0.00075373, 0.00082029,
#        0.00111997, 0.00124207, 0.00202998, 0.00138938, 0.00080948,
#        0.00083037, 0.00063081, 0.00059949, 0.00062952, 0.00068411,
#        0.00074866, 0.00069217, 0.00074373, 0.00075826, 0.00071284,
#        0.00067131, 0.00075397, 0.00073394, 0.0007587 , 0.00078965,
#        0.00079579, 0.00084819, 0.00302074, 0.00196458, 0.00079385,
#        0.00071532, 0.00073681, 0.00076312, 0.00079617, 0.00089153,
#        0.00064361, 0.00073158, 0.00071294, 0.00085183, 0.00079493,
#        0.00124776, 0.00066957, 0.00077494, 0.00069866, 0.00072089,
#        0.00104465, 0.00105022, 0.00115342, 0.00089406, 0.00072335,
#        0.00062451, 0.00062552, 0.00063249, 0.0006141 , 0.00074713,
#        0.0006803 , 0.00072   , 0.00061615, 0.00065574, 0.00073967,
#        0.00071174, 0.00071293, 0.00071257, 0.0006038 , 0.00060401,
#        0.0006367 , 0.00065441, 0.0039233 , 0.0021195 , 0.00103028,
#        0.0007167 , 0.00084732, 0.00077375, 0.00074797, 0.00072709,
#        0.0006463 , 0.00065779, 0.00067654, 0.00061437, 0.0006221 ,
#        0.00064441, 0.00073159, 0.00062893, 0.00057867, 0.00071365,
#        0.0009301 , 0.00079884, 0.00505951, 0.00137702, 0.00892726,
#        0.00093302, 0.00354148, 0.00250118, 0.00194098, 0.00395385,
#        0.00875096, 0.00812797, 0.00120309, 0.00073208, 0.00082789,
#        0.00066515, 0.0054774 , 0.02873703, 0.00693167, 0.00259067,
#        0.00120225, 0.00066177, 0.00060341, 0.00082066, 0.0025853 ,
#        0.00069152, 0.00068711, 0.00086337])

# %%
threshold = 0.009
importances = np.array(rf.feature_importances_)
names = np.array(rf.feature_names_in_,)

importances_filtered = np.where(importances >= threshold)[0]
features_filtered = names[importances_filtered]
importances_filtered = importances[importances_filtered]
importances_df = pd.DataFrame({"Features" : features_filtered, 
                               "Importance rate" : importances_filtered})
importances_df.sort_values(by=['Importance rate'], ascending=False, inplace=True)
fig, ax = plt.subplots(figsize=(20, 10))                        
g = sns.barplot(x=importances_df['Importance rate'], 
                y=importances_df['Features'],
                ax=ax)
g.set_title("Top Feature importances", fontsize=14)
for value in g.containers:
    g.bar_label(value)

# %% [markdown]
# <h3>Distribution of correct/incorrect species classifications by users</h3>

# %%
def count_zeros_ones(arr_list):
    num_of_zeros = 0
    num_of_ones = 0
    for arr in arr_list:
        num_of_zeros += np.count_nonzero(arr == 0)
        num_of_ones += np.count_nonzero(arr >= 1)
    return (num_of_zeros, num_of_ones)

species = ['comcuc', 'cowpig1', 'eucdov',
            'eueowl1', 'grswoo', 'tawowl1']
positive = []
zeros = []
for elem in species:
    res = count_zeros_ones(BirdsData('ptichki').find_classification_distibution(elem))
    zeros.append(res[0])
    positive.append(res[1])


x = np.arange(len(species))
width = 0.30  # the width of the bars

fig, ax = plt.subplots(figsize=(15, 10))
rects1 = ax.bar(x - width/2, positive, width, label='Correct classification')
rects2 = ax.bar(x + width/2, zeros, width, label='Incorrect classification')

ax.set_title('Distribution of classifications by users')
ax.set_ylabel('Values')
ax.set_xticks(x)
ax.set_xticklabels(species)
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 14
#      12 zeros = []
#      13 for elem in species:
# ---> 14     res = count_zeros_ones(BirdsData('ptichki').find_classification_distibution(elem))
#      15     zeros.append(res[0])
#      16     positive.append(res[1])
#
# File ~/Desktop/JKU/Semester 4/ML Pattern Classification/BirdExplore.py:275, in BirdsData.find_classification_distibution(self, species)
#     273 for i in range(len(labels_paths)):
#     274     labels_ar_list.append(np.load(labels_paths[i]))
# --> 275 return np.array(labels_ar_list)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (200, 100) + inhomogeneous part.

# %%
BirdsData('ptichki').species_call_distribution()

# %%
BirdsData('ptichki').plot_duration_means()

# %%
print(BirdsData('ptichki').cor_feat_label())
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(BirdsData('ptichki').cor_feat_label())
#
# File ~/Desktop/JKU/Semester 4/ML Pattern Classification/BirdExplore.py:257, in cor_feat_label(self)
#     256 def cor_feat_label(self):
# --> 257     c = BirdsData('ptichki')
#     258     X = c.united_dataset()[:, 0:548]
#     259     y = c.united_dataset()[:, -1]
#
# File ~/Desktop/JKU/Semester 4/ML Pattern Classification/BirdExplore.py:44, in BirdsData.united_dataset(self)
#      40 def united_dataset(self):
#      42     birds = [os.path.join(self.project_folder, b)
#      43              for b in os.listdir(self.project_folder)]
# ---> 44     all_files = [os.path.join(bird, f)
#      45                  for bird in birds for f in os.listdir(bird)]
#      46     all_files = sorted([f for f in all_files if not 'labels' in f])
#      48     comcuc = [f for f in all_files if 'comcuc' in f]
#
# File ~/Desktop/JKU/Semester 4/ML Pattern Classification/BirdExplore.py:45, in <listcomp>(.0)
#      40 def united_dataset(self):
#      42     birds = [os.path.join(self.project_folder, b)
#      43              for b in os.listdir(self.project_folder)]
#      44     all_files = [os.path.join(bird, f)
# ---> 45                  for bird in birds for f in os.listdir(bird)]
#      46     all_files = sorted([f for f in all_files if not 'labels' in f])
#      48     comcuc = [f for f in all_files if 'comcuc' in f]
#
# NotADirectoryError: [Errno 20] Not a directory: 'ptichki/.DS_Store'
