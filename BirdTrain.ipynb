# %% [markdown]
# <a href="https://colab.research.google.com/github/timoniko/ML_Pattern_Classification/blob/main/BirdTrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import torch
from torch import nn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from google.colab import drive
from sklearn.model_selection import KFold
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset
import torch.nn.functional as F
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from tqdm import tqdm
from sklearn.metrics import f1_score
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
dataset = pd.read_csv('/content/drive/MyDrive/bird.csv')

# %%
targets = {'other': 0,
            'comcuc': 1,
            'cowpig1': 2,
            'eucdov': 3,
            'eueowl1': 4,
            'grswoo': 5,
            'tawowl1': 6}

dataset['target'] = dataset['target'].map(targets)

# %%
dataset = np.array(dataset)

dataset_t = np.array(dataset)


X = dataset[:, 0:-1]
y = dataset[:, -1]

sampling_strategy_over = {
    0: len(np.where(y == 0)[0]),
    1: 15000,
    2: 15000,
    3: 15000,
    4: 15000,
    5: 15000,
    6: 15000
}


sampling_strategy_under = {
    0: len(np.where(y == 0)[0]),
    1: 15000,
    2: 15000,
    3: 15000,
    4: 15000,
    5: 15000,
    6: 15000
}

over = SMOTE(sampling_strategy=sampling_strategy_over)
under = RandomUnderSampler(sampling_strategy=sampling_strategy_under)
steps = [('o', over), ('u', under)]
pipeline = Pipeline(steps=steps)
X, y = pipeline.fit_resample(X, y)
X = StandardScaler().fit_transform(X)

# %%
len(np.where(y == 0)[0])
# Out:
# 59750

# %%
class BirdDataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype = torch.float32)
        self.y = torch.tensor(y, dtype = torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        features = self.X[idx]
        target = self.y[idx]
        return features, target

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
class BirdNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, num_layers, dropout_prob):
        super(BirdNet, self).__init__()
        self.layers = nn.ModuleList()
        for i in range(num_layers):
            self.layers.append(nn.Sequential(
                nn.Linear(hidden_size, hidden_size),
                nn.BatchNorm1d(hidden_size),
                nn.ReLU(),
                nn.Dropout(dropout_prob)
            ))
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc_final = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x = self.fc1(x)
        for layer in self.layers:
            x = layer(x)
        x = self.fc_final(x)
        return x

# %%
#loss
n_classes = len(np.unique(y))

n_layers = 2

bird_net = BirdNet(X.shape[1], X.shape[1] * 2, n_classes, 2, 0.3).to(device)

loss_fn = nn.CrossEntropyLoss()

# %%
def train_network(k_folds, num_epochs, n_layers, input_f):
    kfold = KFold(n_splits=k_folds, shuffle=True)
    results = {}
    f1_scores = []
    accuracies = []
    
    for fold, (train_ids, test_ids) in enumerate(kfold.split(dataset)):
        print(f'FOLD {fold}')
        print('--------------------------------')
        
        train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
        test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)
        
        trainloader = torch.utils.data.DataLoader(
            dataset, batch_size=64, sampler=train_subsampler)
        testloader = torch.utils.data.DataLoader(
            dataset, batch_size=64, sampler=test_subsampler)
        
        network = BirdNet(input_f, input_f * 2, n_classes, n_layers, 0.3).to(device)
        optimizer = torch.optim.Adam(network.parameters(), lr=0.01)
        loss_fn = torch.nn.CrossEntropyLoss()
        
        for epoch in range(0, num_epochs):
            print(f'Starting epoch {epoch+1}')
            current_loss = 0.0
            
            for i, data in enumerate(trainloader, 0):
                inputs, targets = data[0].to(device, dtype=torch.float32), data[1].to(device, dtype=torch.long)
                optimizer.zero_grad()
                outputs = network(inputs)
                loss = loss_fn(outputs, targets)
                loss.backward()
                optimizer.step()
                
                current_loss += loss.item()
                if i % 50 == 49:
                    print('Loss after mini-batch %5d: %.3f' % (i + 1, current_loss / 50))
                    current_loss = 0.0
                    
        print('Training process has finished. Saving trained model.')
        save_path = f'./model-fold-{fold}_rs.pth'
        torch.save(network.state_dict(), save_path)

        # Evaluation for this fold
        correct, total = 0, 0
        y_true, y_pred = [], []
        
        with torch.no_grad():
            for i, data in enumerate(testloader, 0):
                inputs, targets = data[0].to(device, dtype=torch.float32), data[1].to(device, dtype=torch.long)
                outputs = network(inputs)
                _, predicted = torch.max(outputs.data, 1)
                
                total += targets.size(0)
                correct += (predicted == targets).sum().item()
                
                y_true.extend(targets.cpu().numpy().tolist())
                y_pred.extend(predicted.cpu().numpy().tolist())
        
        accuracy = 100.0 * correct / total
        f1 = f1_score(y_true, y_pred, average='weighted') * 100
        
        print(f'Accuracy for fold {fold}: {accuracy} %')
        print(f'F1 score for fold {fold}: {f1}')
        print('--------------------------------')
        
        results[fold] = accuracy
        accuracies.append(accuracy)
        f1_scores.append(f1)

    print(f'K-FOLD CROSS VALIDATION RESULTS FOR {k_folds} FOLDS')
    print('--------------------------------')
    
    for key, value in results.items():
        print(f'Fold {key}: {value} %')
        
    print(f'Average Accuracy: {sum(accuracies)/len(accuracies)} %')
    print(f'Average F1 score: {sum(f1_scores)/len(f1_scores)} %')

    acc = sum(accuracies)/len(accuracies)
    f1 = sum(f1_scores)/len(f1_scores)

    return acc, f1

# %%
bird_data = BirdDataset(X, y)
trainset, testset = random_split(bird_data, [0.7, 0.3])
dataset = ConcatDataset([trainset, testset])

acc, f1 = train_network(k_folds = 16, num_epochs = 50, n_layers = 2, input_f = X.shape[1])
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss after mini-batch   400: 0.094
# Loss after mini-batch   450: 0.098
# Loss after mini-batch   500: 0.106
# Loss after mini-batch   550: 0.085
# Loss after mini-batch   600: 0.089
# Loss after mini-batch   650: 0.114
# Loss after mini-batch   700: 0.134
# Loss after mini-batch   750: 0.099
# Loss after mini-batch   800: 0.120
# Loss after mini-batch   850: 0.108
# Loss after mini-batch   900: 0.094
# Loss after mini-batch   950: 0.119
# Loss after mini-batch  1000: 0.094
# Loss after mini-batch  1050: 0.102
# Loss after mini-batch  1100: 0.112
# Loss after mini-batch  1150: 0.096
# Loss after mini-batch  1200: 0.108
# Loss after mini-batch  1250: 0.105
# Loss after mini-batch  1300: 0.091
# Loss after mini-batch  1350: 0.097
# Loss after mini-batch  1400: 0.116
# Loss after mini-batch  1450: 0.117
# Loss after mini-batch  1500: 0.111
# Loss after mini-batch  1550: 0.103
# Loss after mini-batch  1600: 0.077
# Loss after mini-batch  1650: 0.095
# Loss after mini-batch  1700: 0.114
# Loss after mini-batch  1750: 0.085
# Loss after mini-batch  1800: 0.102
# Loss after mini-batch  1850: 0.119
# Loss after mini-batch  1900: 0.109
# Loss after mini-batch  1950: 0.107
# Loss after mini-batch  2000: 0.094
# Loss after mini-batch  2050: 0.100
# Loss after mini-batch  2100: 0.112
# Loss after mini-batch  2150: 0.103
# Starting epoch 39
# Loss after mini-batch    50: 0.099
# Loss after mini-batch   100: 0.116
# Loss after mini-batch   150: 0.093
# Loss after mini-batch   200: 0.086
# Loss after mini-batch   250: 0.084
# Loss after mini-batch   300: 0.097
# Loss after mini-batch   350: 0.096
# Loss after mini-batch   400: 0.107
# Loss after mini-batch   450: 0.106
# Loss after mini-batch   500: 0.089
# Loss after mini-batch   550: 0.089
# Loss after mini-batch   600: 0.112
# Loss after mini-batch   650: 0.109
# Loss after mini-batch   700: 0.110
# Loss after mini-batch   750: 0.109
# Loss after mini-batch   800: 0.093
# Loss after mini-batch   850: 0.102
# Loss after mini-batch   900: 0.094
# Loss after mini-batch   950: 0.095
# Loss after mini-batch  1000: 0.096
# Loss after mini-batch  1050: 0.096
# Loss after mini-batch  1100: 0.111
# Loss after mini-batch  1150: 0.094
# Loss after mini-batch  1200: 0.116
# Loss after mini-batch  1250: 0.087
# Loss after mini-batch  1300: 0.094
# Loss after mini-batch  1350: 0.097
# Loss after mini-batch  1400: 0.098
# Loss after mini-batch  1450: 0.093
# Loss after mini-batch  1500: 0.111
# Loss after mini-batch  1550: 0.091
# Loss after mini-batch  1600: 0.105
# Loss after mini-batch  1650: 0.102
# Loss after mini-batch  1700: 0.104
# Loss after mini-batch  1750: 0.101
# Loss after mini-batch  1800: 0.088
# Loss after mini-batch  1850: 0.087
# Loss after mini-batch  1900: 0.089
# Loss after mini-batch  1950: 0.100
# Loss after mini-batch  2000: 0.109
# Loss after mini-batch  2050: 0.112
# Loss after mini-batch  2100: 0.116
# Loss after mini-batch  2150: 0.114
# Starting epoch 40
# Loss after mini-batch    50: 0.083
# Loss after mini-batch   100: 0.093
# Loss after mini-batch   150: 0.090
# Loss after mini-batch   200: 0.091
# Loss after mini-batch   250: 0.105
# Loss after mini-batch   300: 0.089
# Loss after mini-batch   350: 0.110
# Loss after mini-batch   400: 0.085
# Loss after mini-batch   450: 0.104
# Loss after mini-batch   500: 0.091
# Loss after mini-batch   550: 0.090
# Loss after mini-batch   600: 0.092
# Loss after mini-batch   650: 0.080
# Loss after mini-batch   700: 0.086
# Loss after mini-batch   750: 0.088
# Loss after mini-batch   800: 0.093
# Loss after mini-batch   850: 0.107
# Loss after mini-batch   900: 0.091
# Loss after mini-batch   950: 0.093
# Loss after mini-batch  1000: 0.091
# Loss after mini-batch  1050: 0.100
# Loss after mini-batch  1100: 0.109
# Loss after mini-batch  1150: 0.104
# Loss after mini-batch  1200: 0.111
# Loss after mini-batch  1250: 0.101
# Loss after mini-batch  1300: 0.099
# Loss after mini-batch  1350: 0.113
# Loss after mini-batch  1400: 0.102
# Loss after mini-batch  1450: 0.110
# Loss after mini-batch  1500: 0.089
# Loss after mini-batch  1550: 0.103
# Loss after mini-batch  1600: 0.121
# Loss after mini-batch  1650: 0.108
# Loss after mini-batch  1700: 0.108
# Loss after mini-batch  1750: 0.109
# Loss after mini-batch  1800: 0.099
# Loss after mini-batch  1850: 0.103
# Loss after mini-batch  1900: 0.110
# Loss after mini-batch  1950: 0.081
# Loss after mini-batch  2000: 0.116
# Loss after mini-batch  2050: 0.124
# Loss after mini-batch  2100: 0.095
# Loss after mini-batch  2150: 0.098
# Starting epoch 41
# Loss after mini-batch    50: 0.100
# Loss after mini-batch   100: 0.103
# Loss after mini-batch   150: 0.087
# Loss after mini-batch   200: 0.098
# Loss after mini-batch   250: 0.113
# Loss after mini-batch   300: 0.092
# Loss after mini-batch   350: 0.091
# Loss after mini-batch   400: 0.104
# Loss after mini-batch   450: 0.098
# Loss after mini-batch   500: 0.097
# Loss after mini-batch   550: 0.101
# Loss after mini-batch   600: 0.094
# Loss after mini-batch   650: 0.079
# Loss after mini-batch   700: 0.100
# Loss after mini-batch   750: 0.093
# Loss after mini-batch   800: 0.085
# Loss after mini-batch   850: 0.096
# Loss after mini-batch   900: 0.093
# Loss after mini-batch   950: 0.117
# Loss after mini-batch  1000: 0.102
# Loss after mini-batch  1050: 0.097
# Loss after mini-batch  1100: 0.093
# Loss after mini-batch  1150: 0.095
# Loss after mini-batch  1200: 0.098
# Loss after mini-batch  1250: 0.103
# Loss after mini-batch  1300: 0.108
# Loss after mini-batch  1350: 0.102
# Loss after mini-batch  1400: 0.099
# Loss after mini-batch  1450: 0.097
# Loss after mini-batch  1500: 0.114
# Loss after mini-batch  1550: 0.090
# Loss after mini-batch  1600: 0.099
# Loss after mini-batch  1650: 0.085
# Loss after mini-batch  1700: 0.095
# Loss after mini-batch  1750: 0.103
# Loss after mini-batch  1800: 0.103
# Loss after mini-batch  1850: 0.100
# Loss after mini-batch  1900: 0.095
# Loss after mini-batch  1950: 0.078
# Loss after mini-batch  2000: 0.089
# Loss after mini-batch  2050: 0.097
# Loss after mini-batch  2100: 0.099
# Loss after mini-batch  2150: 0.105
# Starting epoch 42
# Loss after mini-batch    50: 0.093
# Loss after mini-batch   100: 0.084
# Loss after mini-batch   150: 0.091
# Loss after mini-batch   200: 0.101
# Loss after mini-batch   250: 0.086
# Loss after mini-batch   300: 0.089
# Loss after mini-batch   350: 0.115
# Loss after mini-batch   400: 0.102
# Loss after mini-batch   450: 0.090
# Loss after mini-batch   500: 0.088
# Loss after mini-batch   550: 0.095
# Loss after mini-batch   600: 0.084
# Loss after mini-batch   650: 0.085
# Loss after mini-batch   700: 0.100
# Loss after mini-batch   750: 0.092
# Loss after mini-batch   800: 0.098
# Loss after mini-batch   850: 0.114
# Loss after mini-batch   900: 0.108
# Loss after mini-batch   950: 0.093
# Loss after mini-batch  1000: 0.099
# Loss after mini-batch  1050: 0.092
# Loss after mini-batch  1100: 0.100
# Loss after mini-batch  1150: 0.102
# Loss after mini-batch  1200: 0.086
# Loss after mini-batch  1250: 0.087
# Loss after mini-batch  1300: 0.101
# Loss after mini-batch  1350: 0.104
# Loss after mini-batch  1400: 0.103
# Loss after mini-batch  1450: 0.110
# Loss after mini-batch  1500: 0.095
# Loss after mini-batch  1550: 0.103
# Loss after mini-batch  1600: 0.113
# Loss after mini-batch  1650: 0.092
# Loss after mini-batch  1700: 0.106
# Loss after mini-batch  1750: 0.107
# Loss after mini-batch  1800: 0.080
# Loss after mini-batch  1850: 0.110
# Loss after mini-batch  1900: 0.102
# Loss after mini-batch  1950: 0.099
# Loss after mini-batch  2000: 0.092
# Loss after mini-batch  2050: 0.095
# Loss after mini-batch  2100: 0.111
# Loss after mini-batch  2150: 0.080
# Starting epoch 43
# Loss after mini-batch    50: 0.090
# Loss after mini-batch   100: 0.093
# Loss after mini-batch   150: 0.100
# Loss after mini-batch   200: 0.080
# Loss after mini-batch   250: 0.095
# Loss after mini-batch   300: 0.096
# Loss after mini-batch   350: 0.076
# Loss after mini-batch   400: 0.076
# Loss after mini-batch   450: 0.078
# Loss after mini-batch   500: 0.091
# Loss after mini-batch   550: 0.095
# Loss after mini-batch   600: 0.108
# Loss after mini-batch   650: 0.103
# Loss after mini-batch   700: 0.098
# Loss after mini-batch   750: 0.085
# Loss after mini-batch   800: 0.089
# Loss after mini-batch   850: 0.086
# Loss after mini-batch   900: 0.108
# Loss after mini-batch   950: 0.098
# Loss after mini-batch  1000: 0.097
# Loss after mini-batch  1050: 0.102
# Loss after mini-batch  1100: 0.085
# Loss after mini-batch  1150: 0.098
# Loss after mini-batch  1200: 0.092
# Loss after mini-batch  1250: 0.094
# Loss after mini-batch  1300: 0.109
# Loss after mini-batch  1350: 0.103
# Loss after mini-batch  1400: 0.103
# Loss after mini-batch  1450: 0.093
# Loss after mini-batch  1500: 0.091
# Loss after mini-batch  1550: 0.088
# Loss after mini-batch  1600: 0.098
# Loss after mini-batch  1650: 0.112
# Loss after mini-batch  1700: 0.099
# Loss after mini-batch  1750: 0.113
# Loss after mini-batch  1800: 0.088
# Loss after mini-batch  1850: 0.084
# Loss after mini-batch  1900: 0.095
# Loss after mini-batch  1950: 0.087
# Loss after mini-batch  2000: 0.101
# Loss after mini-batch  2050: 0.097
# Loss after mini-batch  2100: 0.097
# Loss after mini-batch  2150: 0.084
# Starting epoch 44
# Loss after mini-batch    50: 0.099
# Loss after mini-batch   100: 0.095
# Loss after mini-batch   150: 0.099
# Loss after mini-batch   200: 0.086
# Loss after mini-batch   250: 0.090
# Loss after mini-batch   300: 0.091
# Loss after mini-batch   350: 0.075
# Loss after mini-batch   400: 0.098
# Loss after mini-batch   450: 0.091
# Loss after mini-batch   500: 0.097
# Loss after mini-batch   550: 0.065
# Loss after mini-batch   600: 0.105
# Loss after mini-batch   650: 0.087
# Loss after mini-batch   700: 0.091
# Loss after mini-batch   750: 0.106
# Loss after mini-batch   800: 0.092
# Loss after mini-batch   850: 0.085
# Loss after mini-batch   900: 0.104
# Loss after mini-batch   950: 0.086
# Loss after mini-batch  1000: 0.096
# Loss after mini-batch  1050: 0.091
# Loss after mini-batch  1100: 0.081
# Loss after mini-batch  1150: 0.102
# Loss after mini-batch  1200: 0.110
# Loss after mini-batch  1250: 0.087
# Loss after mini-batch  1300: 0.083
# Loss after mini-batch  1350: 0.094
# Loss after mini-batch  1400: 0.105
# Loss after mini-batch  1450: 0.092
# Loss after mini-batch  1500: 0.093
# Loss after mini-batch  1550: 0.101
# Loss after mini-batch  1600: 0.113
# Loss after mini-batch  1650: 0.100
# Loss after mini-batch  1700: 0.108
# Loss after mini-batch  1750: 0.091
# Loss after mini-batch  1800: 0.104
# Loss after mini-batch  1850: 0.100
# Loss after mini-batch  1900: 0.099
# Loss after mini-batch  1950: 0.098
# Loss after mini-batch  2000: 0.090
# Loss after mini-batch  2050: 0.094
# Loss after mini-batch  2100: 0.097
# Loss after mini-batch  2150: 0.086
# Starting epoch 45
# Loss after mini-batch    50: 0.089
# Loss after mini-batch   100: 0.079
# Loss after mini-batch   150: 0.075
# Loss after mini-batch   200: 0.078
# Loss after mini-batch   250: 0.069
# Loss after mini-batch   300: 0.085
# Loss after mini-batch   350: 0.094
# Loss after mini-batch   400: 0.106
# Loss after mini-batch   450: 0.090
# Loss after mini-batch   500: 0.101
# Loss after mini-batch   550: 0.089
# Loss after mini-batch   600: 0.077
# Loss after mini-batch   650: 0.098
# Loss after mini-batch   700: 0.088
# Loss after mini-batch   750: 0.101
# Loss after mini-batch   800: 0.079
# Loss after mini-batch   850: 0.080
# Loss after mini-batch   900: 0.096
# Loss after mini-batch   950: 0.103
# Loss after mini-batch  1000: 0.089
# Loss after mini-batch  1050: 0.090
# Loss after mini-batch  1100: 0.097
# Loss after mini-batch  1150: 0.086
# Loss after mini-batch  1200: 0.093
# Loss after mini-batch  1250: 0.102
# Loss after mini-batch  1300: 0.086
# Loss after mini-batch  1350: 0.093
# Loss after mini-batch  1400: 0.090
# Loss after mini-batch  1450: 0.100
# Loss after mini-batch  1500: 0.086
# Loss after mini-batch  1550: 0.110
# Loss after mini-batch  1600: 0.087
# Loss after mini-batch  1650: 0.089
# Loss after mini-batch  1700: 0.089
# Loss after mini-batch  1750: 0.117
# Loss after mini-batch  1800: 0.095
# Loss after mini-batch  1850: 0.108
# Loss after mini-batch  1900: 0.115
# Loss after mini-batch  1950: 0.105
# Loss after mini-batch  2000: 0.116
# Loss after mini-batch  2050: 0.105
# Loss after mini-batch  2100: 0.090
# Loss after mini-batch  2150: 0.101
# Starting epoch 46
# Loss after mini-batch    50: 0.090
# Loss after mini-batch   100: 0.085
# Loss after mini-batch   150: 0.067
# Loss after mini-batch   200: 0.083
# Loss after mini-batch   250: 0.085
# Loss after mini-batch   300: 0.081
# Loss after mini-batch   350: 0.088
# Loss after mini-batch   400: 0.095
# Loss after mini-batch   450: 0.100
# Loss after mini-batch   500: 0.094
# Loss after mini-batch   550: 0.090
# Loss after mini-batch   600: 0.085
# Loss after mini-batch   650: 0.089
# Loss after mini-batch   700: 0.077
# Loss after mini-batch   750: 0.081
# Loss after mini-batch   800: 0.088
# Loss after mini-batch   850: 0.090
# Loss after mini-batch   900: 0.097
# Loss after mini-batch   950: 0.094
# Loss after mini-batch  1000: 0.104
# Loss after mini-batch  1050: 0.084
# Loss after mini-batch  1100: 0.092
# Loss after mini-batch  1150: 0.103
# Loss after mini-batch  1200: 0.072
# Loss after mini-batch  1250: 0.096
# Loss after mini-batch  1300: 0.091
# Loss after mini-batch  1350: 0.100
# Loss after mini-batch  1400: 0.093
# Loss after mini-batch  1450: 0.084
# Loss after mini-batch  1500: 0.103
# Loss after mini-batch  1550: 0.092
# Loss after mini-batch  1600: 0.105
# Loss after mini-batch  1650: 0.079
# Loss after mini-batch  1700: 0.089
# Loss after mini-batch  1750: 0.101
# Loss after mini-batch  1800: 0.094
# Loss after mini-batch  1850: 0.081
# Loss after mini-batch  1900: 0.086
# Loss after mini-batch  1950: 0.097
# Loss after mini-batch  2000: 0.086
# Loss after mini-batch  2050: 0.083
# Loss after mini-batch  2100: 0.080
# Loss after mini-batch  2150: 0.094
# Starting epoch 47
# Loss after mini-batch    50: 0.093
# Loss after mini-batch   100: 0.089
# Loss after mini-batch   150: 0.078
# Loss after mini-batch   200: 0.083
# Loss after mini-batch   250: 0.085
# Loss after mini-batch   300: 0.085
# Loss after mini-batch   350: 0.078
# Loss after mini-batch   400: 0.101
# Loss after mini-batch   450: 0.098
# Loss after mini-batch   500: 0.088
# Loss after mini-batch   550: 0.090
# Loss after mini-batch   600: 0.084
# Loss after mini-batch   650: 0.100
# Loss after mini-batch   700: 0.090
# Loss after mini-batch   750: 0.093
# Loss after mini-batch   800: 0.065
# Loss after mini-batch   850: 0.102
# Loss after mini-batch   900: 0.089
# Loss after mini-batch   950: 0.093
# Loss after mini-batch  1000: 0.077
# Loss after mini-batch  1050: 0.100
# Loss after mini-batch  1100: 0.107
# Loss after mini-batch  1150: 0.099
# Loss after mini-batch  1200: 0.096
# Loss after mini-batch  1250: 0.075
# Loss after mini-batch  1300: 0.124
# Loss after mini-batch  1350: 0.082
# Loss after mini-batch  1400: 0.111
# Loss after mini-batch  1450: 0.082
# Loss after mini-batch  1500: 0.090
# Loss after mini-batch  1550: 0.093
# Loss after mini-batch  1600: 0.084
# Loss after mini-batch  1650: 0.093
# Loss after mini-batch  1700: 0.106
# Loss after mini-batch  1750: 0.080
# Loss after mini-batch  1800: 0.089
# Loss after mini-batch  1850: 0.080
# Loss after mini-batch  1900: 0.089
# Loss after mini-batch  1950: 0.083
# Loss after mini-batch  2000: 0.091
# Loss after mini-batch  2050: 0.091
# Loss after mini-batch  2100: 0.103
# Loss after mini-batch  2150: 0.094
# Starting epoch 48
# Loss after mini-batch    50: 0.079
# Loss after mini-batch   100: 0.095
# Loss after mini-batch   150: 0.092
# Loss after mini-batch   200: 0.084
# Loss after mini-batch   250: 0.084
# Loss after mini-batch   300: 0.086
# Loss after mini-batch   350: 0.090
# Loss after mini-batch   400: 0.085
# Loss after mini-batch   450: 0.095
# Loss after mini-batch   500: 0.084
# Loss after mini-batch   550: 0.081
# Loss after mini-batch   600: 0.076
# Loss after mini-batch   650: 0.096
# Loss after mini-batch   700: 0.091
# Loss after mini-batch   750: 0.087
# Loss after mini-batch   800: 0.081
# Loss after mini-batch   850: 0.099
# Loss after mini-batch   900: 0.099
# Loss after mini-batch   950: 0.089
# Loss after mini-batch  1000: 0.083
# Loss after mini-batch  1050: 0.098
# Loss after mini-batch  1100: 0.073
# Loss after mini-batch  1150: 0.104
# Loss after mini-batch  1200: 0.104
# Loss after mini-batch  1250: 0.086
# Loss after mini-batch  1300: 0.079
# Loss after mini-batch  1350: 0.090
# Loss after mini-batch  1400: 0.112
# Loss after mini-batch  1450: 0.074
# Loss after mini-batch  1500: 0.099
# Loss after mini-batch  1550: 0.078
# Loss after mini-batch  1600: 0.083
# Loss after mini-batch  1650: 0.096
# Loss after mini-batch  1700: 0.089
# Loss after mini-batch  1750: 0.097
# Loss after mini-batch  1800: 0.087
# Loss after mini-batch  1850: 0.079
# Loss after mini-batch  1900: 0.094
# Loss after mini-batch  1950: 0.105
# Loss after mini-batch  2000: 0.102
# Loss after mini-batch  2050: 0.076
# Loss after mini-batch  2100: 0.095
# Loss after mini-batch  2150: 0.082
# Starting epoch 49
# Loss after mini-batch    50: 0.077
# Loss after mini-batch   100: 0.085
# Loss after mini-batch   150: 0.088
# Loss after mini-batch   200: 0.086
# Loss after mini-batch   250: 0.085
# Loss after mini-batch   300: 0.082
# Loss after mini-batch   350: 0.077
# Loss after mini-batch   400: 0.085
# Loss after mini-batch   450: 0.076
# Loss after mini-batch   500: 0.079
# Loss after mini-batch   550: 0.085
# Loss after mini-batch   600: 0.080
# Loss after mini-batch   650: 0.093
# Loss after mini-batch   700: 0.094
# Loss after mini-batch   750: 0.083
# Loss after mini-batch   800: 0.099
# Loss after mini-batch   850: 0.086
# Loss after mini-batch   900: 0.092
# Loss after mini-batch   950: 0.095
# Loss after mini-batch  1000: 0.084
# Loss after mini-batch  1050: 0.086
# Loss after mini-batch  1100: 0.082
# Loss after mini-batch  1150: 0.091
# Loss after mini-batch  1200: 0.094
# Loss after mini-batch  1250: 0.097
# Loss after mini-batch  1300: 0.078
# Loss after mini-batch  1350: 0.095
# Loss after mini-batch  1400: 0.087
# Loss after mini-batch  1450: 0.087
# Loss after mini-batch  1500: 0.097
# Loss after mini-batch  1550: 0.090
# Loss after mini-batch  1600: 0.101
# Loss after mini-batch  1650: 0.105
# Loss after mini-batch  1700: 0.092
# Loss after mini-batch  1750: 0.096
# Loss after mini-batch  1800: 0.079
# Loss after mini-batch  1850: 0.093
# Loss after mini-batch  1900: 0.091
# Loss after mini-batch  1950: 0.087
# Loss after mini-batch  2000: 0.086
# Loss after mini-batch  2050: 0.089
# Loss after mini-batch  2100: 0.089
# Loss after mini-batch  2150: 0.094
# Starting epoch 50
# Loss after mini-batch    50: 0.076
# Loss after mini-batch   100: 0.098
# Loss after mini-batch   150: 0.071
# Loss after mini-batch   200: 0.077
# Loss after mini-batch   250: 0.079
# Loss after mini-batch   300: 0.090
# Loss after mini-batch   350: 0.085
# Loss after mini-batch   400: 0.082
# Loss after mini-batch   450: 0.086
# Loss after mini-batch   500: 0.087
# Loss after mini-batch   550: 0.103
# Loss after mini-batch   600: 0.081
# Loss after mini-batch   650: 0.080
# Loss after mini-batch   700: 0.092
# Loss after mini-batch   750: 0.090
# Loss after mini-batch   800: 0.080
# Loss after mini-batch   850: 0.084
# Loss after mini-batch   900: 0.078
# Loss after mini-batch   950: 0.071
# Loss after mini-batch  1000: 0.101
# Loss after mini-batch  1050: 0.093
# Loss after mini-batch  1100: 0.092
# Loss after mini-batch  1150: 0.095
# Loss after mini-batch  1200: 0.091
# Loss after mini-batch  1250: 0.075
# Loss after mini-batch  1300: 0.078
# Loss after mini-batch  1350: 0.084
# Loss after mini-batch  1400: 0.090
# Loss after mini-batch  1450: 0.093
# Loss after mini-batch  1500: 0.089
# Loss after mini-batch  1550: 0.099
# Loss after mini-batch  1600: 0.084
# Loss after mini-batch  1650: 0.078
# Loss after mini-batch  1700: 0.095
# Loss after mini-batch  1750: 0.100
# Loss after mini-batch  1800: 0.093
# Loss after mini-batch  1850: 0.080
# Loss after mini-batch  1900: 0.090
# Loss after mini-batch  1950: 0.085
# Loss after mini-batch  2000: 0.083
# Loss after mini-batch  2050: 0.082
# Loss after mini-batch  2100: 0.078
# Loss after mini-batch  2150: 0.092
# Training process has finished. Saving trained model.
# Accuracy for fold 13: 94.81782241692488 %
# F1 score for fold 13: 94.81900787231717
# --------------------------------
# FOLD 14
# --------------------------------
# Starting epoch 1
# Loss after mini-batch    50: 1.204
# Loss after mini-batch   100: 0.834
# Loss after mini-batch   150: 0.653
# Loss after mini-batch   200: 0.627
# Loss after mini-batch   250: 0.594
# Loss after mini-batch   300: 0.638
# Loss after mini-batch   350: 0.558
# Loss after mini-batch   400: 0.553
# Loss after mini-batch   450: 0.504
# Loss after mini-batch   500: 0.481
# Loss after mini-batch   550: 0.480
# Loss after mini-batch   600: 0.495
# Loss after mini-batch   650: 0.480
# Loss after mini-batch   700: 0.473
# Loss after mini-batch   750: 0.440
# Loss after mini-batch   800: 0.426
# Loss after mini-batch   850: 0.435
# Loss after mini-batch   900: 0.455
# Loss after mini-batch   950: 0.450
# Loss after mini-batch  1000: 0.433
# Loss after mini-batch  1050: 0.422
# Loss after mini-batch  1100: 0.408
# Loss after mini-batch  1150: 0.395
# Loss after mini-batch  1200: 0.410
# Loss after mini-batch  1250: 0.415
# Loss after mini-batch  1300: 0.393
# Loss after mini-batch  1350: 0.425
# Loss after mini-batch  1400: 0.385
# Loss after mini-batch  1450: 0.415
# Loss after mini-batch  1500: 0.412
# Loss after mini-batch  1550: 0.412
# Loss after mini-batch  1600: 0.386
# Loss after mini-batch  1650: 0.406
# Loss after mini-batch  1700: 0.391
# Loss after mini-batch  1750: 0.375
# Loss after mini-batch  1800: 0.419
# Loss after mini-batch  1850: 0.373
# Loss after mini-batch  1900: 0.386
# Loss after mini-batch  1950: 0.401
# Loss after mini-batch  2000: 0.358
# Loss after mini-batch  2050: 0.415
# Loss after mini-batch  2100: 0.357
# Loss after mini-batch  2150: 0.346
# Starting epoch 2
# Loss after mini-batch    50: 0.370
# Loss after mini-batch   100: 0.355
# Loss after mini-batch   150: 0.350
# Loss after mini-batch   200: 0.356
# Loss after mini-batch   250: 0.371
# Loss after mini-batch   300: 0.381
# Loss after mini-batch   350: 0.356
# Loss after mini-batch   400: 0.367
# Loss after mini-batch   450: 0.376
# Loss after mini-batch   500: 0.355
# Loss after mini-batch   550: 0.379
# Loss after mini-batch   600: 0.350
# Loss after mini-batch   650: 0.356
# Loss after mini-batch   700: 0.333
# Loss after mini-batch   750: 0.387
# Loss after mini-batch   800: 0.377
# Loss after mini-batch   850: 0.358
# Loss after mini-batch   900: 0.351
# Loss after mini-batch   950: 0.335
# Loss after mini-batch  1000: 0.333
# Loss after mini-batch  1050: 0.368
# Loss after mini-batch  1100: 0.374
# Loss after mini-batch  1150: 0.347
# Loss after mini-batch  1200: 0.352
# Loss after mini-batch  1250: 0.377
# Loss after mini-batch  1300: 0.347
# Loss after mini-batch  1350: 0.348
# Loss after mini-batch  1400: 0.327
# Loss after mini-batch  1450: 0.351
# Loss after mini-batch  1500: 0.347
# Loss after mini-batch  1550: 0.351
# Loss after mini-batch  1600: 0.343
# Loss after mini-batch  1650: 0.357
# Loss after mini-batch  1700: 0.336
# Loss after mini-batch  1750: 0.349
# Loss after mini-batch  1800: 0.353
# Loss after mini-batch  1850: 0.315
# Loss after mini-batch  1900: 0.337
# Loss after mini-batch  1950: 0.336
# Loss after mini-batch  2000: 0.349
# Loss after mini-batch  2050: 0.326
# Loss after mini-batch  2100: 0.341
# Loss after mini-batch  2150: 0.353
# Starting epoch 3
# Loss after mini-batch    50: 0.306
# Loss after mini-batch   100: 0.314
# Loss after mini-batch   150: 0.334
# Loss after mini-batch   200: 0.317
# Loss after mini-batch   250: 0.323
# Loss after mini-batch   300: 0.336
# Loss after mini-batch   350: 0.296
# Loss after mini-batch   400: 0.321
# Loss after mini-batch   450: 0.331
# Loss after mini-batch   500: 0.332
# Loss after mini-batch   550: 0.324
# Loss after mini-batch   600: 0.346
# Loss after mini-batch   650: 0.349
# Loss after mini-batch   700: 0.326
# Loss after mini-batch   750: 0.330
# Loss after mini-batch   800: 0.335
# Loss after mini-batch   850: 0.327
# Loss after mini-batch   900: 0.318
# Loss after mini-batch   950: 0.338
# Loss after mini-batch  1000: 0.354
# Loss after mini-batch  1050: 0.304
# Loss after mini-batch  1100: 0.308
# Loss after mini-batch  1150: 0.332
# Loss after mini-batch  1200: 0.298
# Loss after mini-batch  1250: 0.301
# Loss after mini-batch  1300: 0.305
# Loss after mini-batch  1350: 0.324
# Loss after mini-batch  1400: 0.305
# Loss after mini-batch  1450: 0.319
# Loss after mini-batch  1500: 0.318
# Loss after mini-batch  1550: 0.294
# Loss after mini-batch  1600: 0.318
# Loss after mini-batch  1650: 0.312
# Loss after mini-batch  1700: 0.313
# Loss after mini-batch  1750: 0.313
# Loss after mini-batch  1800: 0.304
# Loss after mini-batch  1850: 0.313
# Loss after mini-batch  1900: 0.319
# Loss after mini-batch  1950: 0.306
# Loss after mini-batch  2000: 0.307
# Loss after mini-batch  2050: 0.278
# Loss after mini-batch  2100: 0.302
# Loss after mini-batch  2150: 0.295
# Starting epoch 4
# Loss after mini-batch    50: 0.301
# Loss after mini-batch   100: 0.310
# Loss after mini-batch   150: 0.307
# Loss after mini-batch   200: 0.313
# Loss after mini-batch   250: 0.307
# Loss after mini-batch   300: 0.287
# Loss after mini-batch   350: 0.307
# Loss after mini-batch   400: 0.277
# Loss after mini-batch   450: 0.304
# Loss after mini-batch   500: 0.295
# Loss after mini-batch   550: 0.292
# Loss after mini-batch   600: 0.311
# Loss after mini-batch   650: 0.304
# Loss after mini-batch   700: 0.301
# Loss after mini-batch   750: 0.263
# Loss after mini-batch   800: 0.301
# Loss after mini-batch   850: 0.284
# Loss after mini-batch   900: 0.304
# Loss after mini-batch   950: 0.294
# Loss after mini-batch  1000: 0.288
# Loss after mini-batch  1050: 0.295
# Loss after mini-batch  1100: 0.276
# Loss after mini-batch  1150: 0.306
# Loss after mini-batch  1200: 0.284
# Loss after mini-batch  1250: 0.278
# Loss after mini-batch  1300: 0.273
# Loss after mini-batch  1350: 0.282
# Loss after mini-batch  1400: 0.262
# Loss after mini-batch  1450: 0.291
# Loss after mini-batch  1500: 0.299
# Loss after mini-batch  1550: 0.284
# Loss after mini-batch  1600: 0.259
# Loss after mini-batch  1650: 0.262
# Loss after mini-batch  1700: 0.280
# Loss after mini-batch  1750: 0.295
# Loss after mini-batch  1800: 0.296
# Loss after mini-batch  1850: 0.295
# Loss after mini-batch  1900: 0.247
# Loss after mini-batch  1950: 0.299
# Loss after mini-batch  2000: 0.282
# Loss after mini-batch  2050: 0.277
# Loss after mini-batch  2100: 0.280
# Loss after mini-batch  2150: 0.288
# Starting epoch 5
# Loss after mini-batch    50: 0.278
# Loss after mini-batch   100: 0.274
# Loss after mini-batch   150: 0.269
# Loss after mini-batch   200: 0.253
# Loss after mini-batch   250: 0.267
# Loss after mini-batch   300: 0.242
# Loss after mini-batch   350: 0.280
# Loss after mini-batch   400: 0.287
# Loss after mini-batch   450: 0.283
# Loss after mini-batch   500: 0.261
# Loss after mini-batch   550: 0.257
# Loss after mini-batch   600: 0.261
# Loss after mini-batch   650: 0.262
# Loss after mini-batch   700: 0.269
# Loss after mini-batch   750: 0.291
# Loss after mini-batch   800: 0.276
# Loss after mini-batch   850: 0.272
# Loss after mini-batch   900: 0.252
# Loss after mini-batch   950: 0.274
# Loss after mini-batch  1000: 0.262
# Loss after mini-batch  1050: 0.254
# Loss after mini-batch  1100: 0.286
# Loss after mini-batch  1150: 0.249
# Loss after mini-batch  1200: 0.278
# Loss after mini-batch  1250: 0.244
# Loss after mini-batch  1300: 0.253
# Loss after mini-batch  1350: 0.263
# Loss after mini-batch  1400: 0.274
# Loss after mini-batch  1450: 0.267
# Loss after mini-batch  1500: 0.267
# Loss after mini-batch  1550: 0.276
# Loss after mini-batch  1600: 0.257
# Loss after mini-batch  1650: 0.259
# Loss after mini-batch  1700: 0.276
# Loss after mini-batch  1750: 0.270
# Loss after mini-batch  1800: 0.253
# Loss after mini-batch  1850: 0.282
# Loss after mini-batch  1900: 0.240
# Loss after mini-batch  1950: 0.288
# Loss after mini-batch  2000: 0.255
# Loss after mini-batch  2050: 0.247
# Loss after mini-batch  2100: 0.274
# Loss after mini-batch  2150: 0.245
# Starting epoch 6
# Loss after mini-batch    50: 0.261
# Loss after mini-batch   100: 0.209
# Loss after mini-batch   150: 0.269
# Loss after mini-batch   200: 0.240
# Loss after mini-batch   250: 0.266
# Loss after mini-batch   300: 0.264
# Loss after mini-batch   350: 0.260
# Loss after mini-batch   400: 0.246
# Loss after mini-batch   450: 0.243
# Loss after mini-batch   500: 0.254
# Loss after mini-batch   550: 0.260
# Loss after mini-batch   600: 0.261
# Loss after mini-batch   650: 0.234
# Loss after mini-batch   700: 0.229
# Loss after mini-batch   750: 0.257
# Loss after mini-batch   800: 0.230
# Loss after mini-batch   850: 0.258
# Loss after mini-batch   900: 0.226
# Loss after mini-batch   950: 0.224
# Loss after mini-batch  1000: 0.271
# Loss after mini-batch  1050: 0.234
# Loss after mini-batch  1100: 0.246
# Loss after mini-batch  1150: 0.257
# Loss after mini-batch  1200: 0.247
# Loss after mini-batch  1250: 0.277
# Loss after mini-batch  1300: 0.246
# Loss after mini-batch  1350: 0.254
# Loss after mini-batch  1400: 0.263
# Loss after mini-batch  1450: 0.248
# Loss after mini-batch  1500: 0.249
# Loss after mini-batch  1550: 0.254
# Loss after mini-batch  1600: 0.246
# Loss after mini-batch  1650: 0.252
# Loss after mini-batch  1700: 0.229
# Loss after mini-batch  1750: 0.228
# Loss after mini-batch  1800: 0.270
# Loss after mini-batch  1850: 0.272
# Loss after mini-batch  1900: 0.230
# Loss after mini-batch  1950: 0.231
# Loss after mini-batch  2000: 0.249
# Loss after mini-batch  2050: 0.275
# Loss after mini-batch  2100: 0.231
# Loss after mini-batch  2150: 0.242
# Starting epoch 7
# Loss after mini-batch    50: 0.236
# Loss after mini-batch   100: 0.245
# Loss after mini-batch   150: 0.249
# Loss after mini-batch   200: 0.248
# Loss after mini-batch   250: 0.237
# Loss after mini-batch   300: 0.223
# Loss after mini-batch   350: 0.232
# Loss after mini-batch   400: 0.225
# Loss after mini-batch   450: 0.231
# Loss after mini-batch   500: 0.213
# Loss after mini-batch   550: 0.247
# Loss after mini-batch   600: 0.247
# Loss after mini-batch   650: 0.243
# Loss after mini-batch   700: 0.249
# Loss after mini-batch   750: 0.224
# Loss after mini-batch   800: 0.210
# Loss after mini-batch   850: 0.233
# Loss after mini-batch   900: 0.238
# Loss after mini-batch   950: 0.234
# Loss after mini-batch  1000: 0.247
# Loss after mini-batch  1050: 0.221
# Loss after mini-batch  1100: 0.263
# Loss after mini-batch  1150: 0.236
# Loss after mini-batch  1200: 0.242
# Loss after mini-batch  1250: 0.236
# Loss after mini-batch  1300: 0.203
# Loss after mini-batch  1350: 0.224
# Loss after mini-batch  1400: 0.229
# Loss after mini-batch  1450: 0.229
# Loss after mini-batch  1500: 0.231
# Loss after mini-batch  1550: 0.223
# Loss after mini-batch  1600: 0.232
# Loss after mini-batch  1650: 0.216
# Loss after mini-batch  1700: 0.215
# Loss after mini-batch  1750: 0.231
# Loss after mini-batch  1800: 0.245
# Loss after mini-batch  1850: 0.207
# Loss after mini-batch  1900: 0.218
# Loss after mini-batch  1950: 0.228
# Loss after mini-batch  2000: 0.250
# Loss after mini-batch  2050: 0.239
# Loss after mini-batch  2100: 0.241
# Loss after mini-batch  2150: 0.225
# Starting epoch 8
# Loss after mini-batch    50: 0.207
# Loss after mini-batch   100: 0.194
# Loss after mini-batch   150: 0.210
# Loss after mini-batch   200: 0.230
# Loss after mini-batch   250: 0.207
# Loss after mini-batch   300: 0.225
# Loss after mini-batch   350: 0.230
# Loss after mini-batch   400: 0.225
# Loss after mini-batch   450: 0.242
# Loss after mini-batch   500: 0.206
# Loss after mini-batch   550: 0.218
# Loss after mini-batch   600: 0.233
# Loss after mini-batch   650: 0.214
# Loss after mini-batch   700: 0.221
# Loss after mini-batch   750: 0.202
# Loss after mini-batch   800: 0.222
# Loss after mini-batch   850: 0.212
# Loss after mini-batch   900: 0.234
# Loss after mini-batch   950: 0.217
# Loss after mini-batch  1000: 0.227
# Loss after mini-batch  1050: 0.219
# Loss after mini-batch  1100: 0.232
# Loss after mini-batch  1150: 0.238
# Loss after mini-batch  1200: 0.197
# Loss after mini-batch  1250: 0.234
# Loss after mini-batch  1300: 0.206
# Loss after mini-batch  1350: 0.220
# Loss after mini-batch  1400: 0.233
# Loss after mini-batch  1450: 0.237
# Loss after mini-batch  1500: 0.219
# Loss after mini-batch  1550: 0.227
# Loss after mini-batch  1600: 0.213
# Loss after mini-batch  1650: 0.239
# Loss after mini-batch  1700: 0.205
# Loss after mini-batch  1750: 0.215
# Loss after mini-batch  1800: 0.201
# Loss after mini-batch  1850: 0.226
# Loss after mini-batch  1900: 0.238
# Loss after mini-batch  1950: 0.226
# Loss after mini-batch  2000: 0.236
# Loss after mini-batch  2050: 0.206
# Loss after mini-batch  2100: 0.231
# Loss after mini-batch  2150: 0.233
# Starting epoch 9
# Loss after mini-batch    50: 0.204
# Loss after mini-batch   100: 0.226
# Loss after mini-batch   150: 0.177
# Loss after mini-batch   200: 0.193
# Loss after mini-batch   250: 0.201
# Loss after mini-batch   300: 0.204
# Loss after mini-batch   350: 0.202
# Loss after mini-batch   400: 0.192
# Loss after mini-batch   450: 0.231
# Loss after mini-batch   500: 0.204
# Loss after mini-batch   550: 0.195
# Loss after mini-batch   600: 0.212
# Loss after mini-batch   650: 0.192
# Loss after mini-batch   700: 0.218
# Loss after mini-batch   750: 0.221
# Loss after mini-batch   800: 0.201
# Loss after mini-batch   850: 0.211
# Loss after mini-batch   900: 0.200
# Loss after mini-batch   950: 0.212
# Loss after mini-batch  1000: 0.210
# Loss after mini-batch  1050: 0.189
# Loss after mini-batch  1100: 0.201
# Loss after mini-batch  1150: 0.223
# Loss after mini-batch  1200: 0.221
# Loss after mini-batch  1250: 0.220
# Loss after mini-batch  1300: 0.197
# Loss after mini-batch  1350: 0.191
# Loss after mini-batch  1400: 0.214
# Loss after mini-batch  1450: 0.223
# Loss after mini-batch  1500: 0.216
# Loss after mini-batch  1550: 0.207
# Loss after mini-batch  1600: 0.207
# Loss after mini-batch  1650: 0.200
# Loss after mini-batch  1700: 0.220
# Loss after mini-batch  1750: 0.202
# Loss after mini-batch  1800: 0.200
# Loss after mini-batch  1850: 0.221
# Loss after mini-batch  1900: 0.208
# Loss after mini-batch  1950: 0.211
# Loss after mini-batch  2000: 0.228
# Loss after mini-batch  2050: 0.220
# Loss after mini-batch  2100: 0.185
# Loss after mini-batch  2150: 0.216
# Starting epoch 10
# Loss after mini-batch    50: 0.198
# Loss after mini-batch   100: 0.193
# Loss after mini-batch   150: 0.176
# Loss after mini-batch   200: 0.198
# Loss after mini-batch   250: 0.182
# Loss after mini-batch   300: 0.218
# Loss after mini-batch   350: 0.184
# Loss after mini-batch   400: 0.204
# Loss after mini-batch   450: 0.212
# Loss after mini-batch   500: 0.184
# Loss after mini-batch   550: 0.206
# Loss after mini-batch   600: 0.181
# Loss after mini-batch   650: 0.211
# Loss after mini-batch   700: 0.207
# Loss after mini-batch   750: 0.194
# Loss after mini-batch   800: 0.208
# Loss after mini-batch   850: 0.202
# Loss after mini-batch   900: 0.205
# Loss after mini-batch   950: 0.198
# Loss after mini-batch  1000: 0.202
# Loss after mini-batch  1050: 0.212
# Loss after mini-batch  1100: 0.193
# Loss after mini-batch  1150: 0.223
# Loss after mini-batch  1200: 0.205
# Loss after mini-batch  1250: 0.181
# Loss after mini-batch  1300: 0.185
# Loss after mini-batch  1350: 0.179
# Loss after mini-batch  1400: 0.200
# Loss after mini-batch  1450: 0.179
# Loss after mini-batch  1500: 0.211
# Loss after mini-batch  1550: 0.226
# Loss after mini-batch  1600: 0.198
# Loss after mini-batch  1650: 0.191
# Loss after mini-batch  1700: 0.209
# Loss after mini-batch  1750: 0.200
# Loss after mini-batch  1800: 0.205
# Loss after mini-batch  1850: 0.224
# Loss after mini-batch  1900: 0.194
# Loss after mini-batch  1950: 0.211
# Loss after mini-batch  2000: 0.196
# Loss after mini-batch  2050: 0.209
# Loss after mini-batch  2100: 0.203
# Loss after mini-batch  2150: 0.182
# Starting epoch 11
# Loss after mini-batch    50: 0.180
# Loss after mini-batch   100: 0.165
# Loss after mini-batch   150: 0.220
# Loss after mini-batch   200: 0.194
# Loss after mini-batch   250: 0.189
# Loss after mini-batch   300: 0.180
# Loss after mini-batch   350: 0.185
# Loss after mini-batch   400: 0.180
# Loss after mini-batch   450: 0.183
# Loss after mini-batch   500: 0.189
# Loss after mini-batch   550: 0.161
# Loss after mini-batch   600: 0.202
# Loss after mini-batch   650: 0.184
# Loss after mini-batch   700: 0.203
# Loss after mini-batch   750: 0.206
# Loss after mini-batch   800: 0.174
# Loss after mini-batch   850: 0.188
# Loss after mini-batch   900: 0.176
# Loss after mini-batch   950: 0.227
# Loss after mini-batch  1000: 0.183
# Loss after mini-batch  1050: 0.189
# Loss after mini-batch  1100: 0.195
# Loss after mini-batch  1150: 0.192
# Loss after mini-batch  1200: 0.189
# Loss after mini-batch  1250: 0.186
# Loss after mini-batch  1300: 0.186
# Loss after mini-batch  1350: 0.194
# Loss after mini-batch  1400: 0.193
# Loss after mini-batch  1450: 0.184
# Loss after mini-batch  1500: 0.196
# Loss after mini-batch  1550: 0.191
# Loss after mini-batch  1600: 0.186
# Loss after mini-batch  1650: 0.191
# Loss after mini-batch  1700: 0.185
# Loss after mini-batch  1750: 0.193
# Loss after mini-batch  1800: 0.196
# Loss after mini-batch  1850: 0.196
# Loss after mini-batch  1900: 0.188
# Loss after mini-batch  1950: 0.206
# Loss after mini-batch  2000: 0.178
# Loss after mini-batch  2050: 0.174
# Loss after mini-batch  2100: 0.194
# Loss after mini-batch  2150: 0.190
# Starting epoch 12
# Loss after mini-batch    50: 0.180
# Loss after mini-batch   100: 0.179
# Loss after mini-batch   150: 0.168
# Loss after mini-batch   200: 0.156
# Loss after mini-batch   250: 0.159
# Loss after mini-batch   300: 0.169
# Loss after mini-batch   350: 0.185
# Loss after mini-batch   400: 0.182
# Loss after mini-batch   450: 0.172
# Loss after mini-batch   500: 0.180
# Loss after mini-batch   550: 0.193
# Loss after mini-batch   600: 0.196
# Loss after mini-batch   650: 0.173
# Loss after mini-batch   700: 0.177
# Loss after mini-batch   750: 0.184
# Loss after mini-batch   800: 0.195
# Loss after mini-batch   850: 0.193
# Loss after mini-batch   900: 0.177
# Loss after mini-batch   950: 0.182
# Loss after mini-batch  1000: 0.178
# Loss after mini-batch  1050: 0.183
# Loss after mini-batch  1100: 0.190
# Loss after mini-batch  1150: 0.192
# Loss after mini-batch  1200: 0.195
# Loss after mini-batch  1250: 0.194
# Loss after mini-batch  1300: 0.185
# Loss after mini-batch  1350: 0.180
# Loss after mini-batch  1400: 0.183
# Loss after mini-batch  1450: 0.186
# Loss after mini-batch  1500: 0.187
# Loss after mini-batch  1550: 0.215
# Loss after mini-batch  1600: 0.183
# Loss after mini-batch  1650: 0.190
# Loss after mini-batch  1700: 0.169
# Loss after mini-batch  1750: 0.173
# Loss after mini-batch  1800: 0.198
# Loss after mini-batch  1850: 0.186
# Loss after mini-batch  1900: 0.197
# Loss after mini-batch  1950: 0.176
# Loss after mini-batch  2000: 0.192
# Loss after mini-batch  2050: 0.184
# Loss after mini-batch  2100: 0.186
# Loss after mini-batch  2150: 0.164
# Starting epoch 13
# Loss after mini-batch    50: 0.175
# Loss after mini-batch   100: 0.158
# Loss after mini-batch   150: 0.142
# Loss after mini-batch   200: 0.171
# Loss after mini-batch   250: 0.159
# Loss after mini-batch   300: 0.153
# Loss after mini-batch   350: 0.196
# Loss after mini-batch   400: 0.169
# Loss after mini-batch   450: 0.183
# Loss after mini-batch   500: 0.175
# Loss after mini-batch   550: 0.191
# Loss after mini-batch   600: 0.176
# Loss after mini-batch   650: 0.182
# Loss after mini-batch   700: 0.171
# Loss after mini-batch   750: 0.137
# Loss after mini-batch   800: 0.181
# Loss after mini-batch   850: 0.184
# Loss after mini-batch   900: 0.180
# Loss after mini-batch   950: 0.166
# Loss after mini-batch  1000: 0.159
# Loss after mini-batch  1050: 0.189
# Loss after mini-batch  1100: 0.182
# Loss after mini-batch  1150: 0.192
# Loss after mini-batch  1200: 0.183
# Loss after mini-batch  1250: 0.189
# Loss after mini-batch  1300: 0.181
# Loss after mini-batch  1350: 0.189
# Loss after mini-batch  1400: 0.181
# Loss after mini-batch  1450: 0.174
# Loss after mini-batch  1500: 0.167
# Loss after mini-batch  1550: 0.155
# Loss after mini-batch  1600: 0.164
# Loss after mini-batch  1650: 0.166
# Loss after mini-batch  1700: 0.187
# Loss after mini-batch  1750: 0.167
# Loss after mini-batch  1800: 0.172
# Loss after mini-batch  1850: 0.192
# Loss after mini-batch  1900: 0.181
# Loss after mini-batch  1950: 0.173
# Loss after mini-batch  2000: 0.194
# Loss after mini-batch  2050: 0.176
# Loss after mini-batch  2100: 0.175
# Loss after mini-batch  2150: 0.187
# Starting epoch 14
# Loss after mini-batch    50: 0.165
# Loss after mini-batch   100: 0.145
# Loss after mini-batch   150: 0.184
# Loss after mini-batch   200: 0.186
# Loss after mini-batch   250: 0.176
# Loss after mini-batch   300: 0.153
# Loss after mini-batch   350: 0.175
# Loss after mini-batch   400: 0.166
# Loss after mini-batch   450: 0.183
# Loss after mini-batch   500: 0.180
# Loss after mini-batch   550: 0.169
# Loss after mini-batch   600: 0.152
# Loss after mini-batch   650: 0.165
# Loss after mini-batch   700: 0.147
# Loss after mini-batch   750: 0.172
# Loss after mini-batch   800: 0.166
# Loss after mini-batch   850: 0.175
# Loss after mini-batch   900: 0.171
# Loss after mini-batch   950: 0.167
# Loss after mini-batch  1000: 0.179
# Loss after mini-batch  1050: 0.165
# Loss after mini-batch  1100: 0.177
# Loss after mini-batch  1150: 0.156
# Loss after mini-batch  1200: 0.176
# Loss after mini-batch  1250: 0.168
# Loss after mini-batch  1300: 0.186
# Loss after mini-batch  1350: 0.165
# Loss after mini-batch  1400: 0.143
# Loss after mini-batch  1450: 0.159
# Loss after mini-batch  1500: 0.173
# Loss after mini-batch  1550: 0.168
# Loss after mini-batch  1600: 0.173
# Loss after mini-batch  1650: 0.165
# Loss after mini-batch  1700: 0.172
# Loss after mini-batch  1750: 0.184
# Loss after mini-batch  1800: 0.166
# Loss after mini-batch  1850: 0.173
# Loss after mini-batch  1900: 0.174
# Loss after mini-batch  1950: 0.192
# Loss after mini-batch  2000: 0.158
# Loss after mini-batch  2050: 0.168
# Loss after mini-batch  2100: 0.173
# Loss after mini-batch  2150: 0.191
# Starting epoch 15
# Loss after mini-batch    50: 0.150
# Loss after mini-batch   100: 0.143
# Loss after mini-batch   150: 0.161
# Loss after mini-batch   200: 0.174
# Loss after mini-batch   250: 0.145
# Loss after mini-batch   300: 0.173
# Loss after mini-batch   350: 0.149
# Loss after mini-batch   400: 0.151
# Loss after mini-batch   450: 0.169
# Loss after mini-batch   500: 0.154
# Loss after mini-batch   550: 0.158
# Loss after mini-batch   600: 0.168
# Loss after mini-batch   650: 0.133
# Loss after mini-batch   700: 0.188
# Loss after mini-batch   750: 0.147
# Loss after mini-batch   800: 0.180
# Loss after mini-batch   850: 0.163
# Loss after mini-batch   900: 0.173
# Loss after mini-batch   950: 0.180
# Loss after mini-batch  1000: 0.171
# Loss after mini-batch  1050: 0.157
# Loss after mini-batch  1100: 0.155
# Loss after mini-batch  1150: 0.162
# Loss after mini-batch  1200: 0.155
# Loss after mini-batch  1250: 0.155
# Loss after mini-batch  1300: 0.167
# Loss after mini-batch  1350: 0.158
# Loss after mini-batch  1400: 0.148
# Loss after mini-batch  1450: 0.184
# Loss after mini-batch  1500: 0.188
# Loss after mini-batch  1550: 0.162
# Loss after mini-batch  1600: 0.174
# Loss after mini-batch  1650: 0.155
# Loss after mini-batch  1700: 0.163
# Loss after mini-batch  1750: 0.180
# Loss after mini-batch  1800: 0.159
# Loss after mini-batch  1850: 0.157
# Loss after mini-batch  1900: 0.155
# Loss after mini-batch  1950: 0.189
# Loss after mini-batch  2000: 0.160
# Loss after mini-batch  2050: 0.183
# Loss after mini-batch  2100: 0.177
# Loss after mini-batch  2150: 0.173
# Starting epoch 16
# Loss after mini-batch    50: 0.154
# Loss after mini-batch   100: 0.152
# Loss after mini-batch   150: 0.161
# Loss after mini-batch   200: 0.148
# Loss after mini-batch   250: 0.165
# Loss after mini-batch   300: 0.146
# Loss after mini-batch   350: 0.173
# Loss after mini-batch   400: 0.159
# Loss after mini-batch   450: 0.162
# Loss after mini-batch   500: 0.133
# Loss after mini-batch   550: 0.174
# Loss after mini-batch   600: 0.171
# Loss after mini-batch   650: 0.173
# Loss after mini-batch   700: 0.166
# Loss after mini-batch   750: 0.150
# Loss after mini-batch   800: 0.139
# Loss after mini-batch   850: 0.165
# Loss after mini-batch   900: 0.165
# Loss after mini-batch   950: 0.144
# Loss after mini-batch  1000: 0.149
# Loss after mini-batch  1050: 0.161
# Loss after mini-batch  1100: 0.156
# Loss after mini-batch  1150: 0.158
# Loss after mini-batch  1200: 0.171
# Loss after mini-batch  1250: 0.164
# Loss after mini-batch  1300: 0.151
# Loss after mini-batch  1350: 0.151
# Loss after mini-batch  1400: 0.167
# Loss after mini-batch  1450: 0.164
# Loss after mini-batch  1500: 0.160
# Loss after mini-batch  1550: 0.159
# Loss after mini-batch  1600: 0.165
# Loss after mini-batch  1650: 0.170
# Loss after mini-batch  1700: 0.169
# Loss after mini-batch  1750: 0.157
# Loss after mini-batch  1800: 0.155
# Loss after mini-batch  1850: 0.144
# Loss after mini-batch  1900: 0.153
# Loss after mini-batch  1950: 0.160
# Loss after mini-batch  2000: 0.169
# Loss after mini-batch  2050: 0.150
# Loss after mini-batch  2100: 0.153
# Loss after mini-batch  2150: 0.183
# Starting epoch 17
# Loss after mini-batch    50: 0.157
# Loss after mini-batch   100: 0.159
# Loss after mini-batch   150: 0.153
# Loss after mini-batch   200: 0.146
# Loss after mini-batch   250: 0.153
# Loss after mini-batch   300: 0.140
# Loss after mini-batch   350: 0.158
# Loss after mini-batch   400: 0.157
# Loss after mini-batch   450: 0.154
# Loss after mini-batch   500: 0.164
# Loss after mini-batch   550: 0.154
# Loss after mini-batch   600: 0.163
# Loss after mini-batch   650: 0.150
# Loss after mini-batch   700: 0.157
# Loss after mini-batch   750: 0.142
# Loss after mini-batch   800: 0.171
# Loss after mini-batch   850: 0.144
# Loss after mini-batch   900: 0.153
# Loss after mini-batch   950: 0.142
# Loss after mini-batch  1000: 0.169
# Loss after mini-batch  1050: 0.153
# Loss after mini-batch  1100: 0.176
# Loss after mini-batch  1150: 0.149
# Loss after mini-batch  1200: 0.164
# Loss after mini-batch  1250: 0.148
# Loss after mini-batch  1300: 0.159
# Loss after mini-batch  1350: 0.161
# Loss after mini-batch  1400: 0.172
# Loss after mini-batch  1450: 0.152
# Loss after mini-batch  1500: 0.165
# Loss after mini-batch  1550: 0.166
# Loss after mini-batch  1600: 0.155
# Loss after mini-batch  1650: 0.168
# Loss after mini-batch  1700: 0.153
# Loss after mini-batch  1750: 0.145
# Loss after mini-batch  1800: 0.148
# Loss after mini-batch  1850: 0.137
# Loss after mini-batch  1900: 0.176
# Loss after mini-batch  1950: 0.178
# Loss after mini-batch  2000: 0.163
# Loss after mini-batch  2050: 0.144
# Loss after mini-batch  2100: 0.141
# Loss after mini-batch  2150: 0.164
# Starting epoch 18
# Loss after mini-batch    50: 0.141
# Loss after mini-batch   100: 0.147
# Loss after mini-batch   150: 0.146
# Loss after mini-batch   200: 0.147
# Loss after mini-batch   250: 0.157
# Loss after mini-batch   300: 0.164
# Loss after mini-batch   350: 0.142
# Loss after mini-batch   400: 0.154
# Loss after mini-batch   450: 0.125
# Loss after mini-batch   500: 0.138
# Loss after mini-batch   550: 0.158
# Loss after mini-batch   600: 0.158
# Loss after mini-batch   650: 0.144
# Loss after mini-batch   700: 0.145
# Loss after mini-batch   750: 0.142
# Loss after mini-batch   800: 0.139
# Loss after mini-batch   850: 0.153
# Loss after mini-batch   900: 0.160
# Loss after mini-batch   950: 0.158
# Loss after mini-batch  1000: 0.136
# Loss after mini-batch  1050: 0.168
# Loss after mini-batch  1100: 0.143
# Loss after mini-batch  1150: 0.167
# Loss after mini-batch  1200: 0.156
# Loss after mini-batch  1250: 0.150
# Loss after mini-batch  1300: 0.132
# Loss after mini-batch  1350: 0.149
# Loss after mini-batch  1400: 0.143
# Loss after mini-batch  1450: 0.176
# Loss after mini-batch  1500: 0.151
# Loss after mini-batch  1550: 0.139
# Loss after mini-batch  1600: 0.169
# Loss after mini-batch  1650: 0.139
# Loss after mini-batch  1700: 0.168
# Loss after mini-batch  1750: 0.157
# Loss after mini-batch  1800: 0.152
# Loss after mini-batch  1850: 0.188
# Loss after mini-batch  1900: 0.165
# Loss after mini-batch  1950: 0.142
# Loss after mini-batch  2000: 0.158
# Loss after mini-batch  2050: 0.153
# Loss after mini-batch  2100: 0.132
# Loss after mini-batch  2150: 0.134
# Starting epoch 19
# Loss after mini-batch    50: 0.124
# Loss after mini-batch   100: 0.143
# Loss after mini-batch   150: 0.142
# Loss after mini-batch   200: 0.147
# Loss after mini-batch   250: 0.137
# Loss after mini-batch   300: 0.128
# Loss after mini-batch   350: 0.147
# Loss after mini-batch   400: 0.143
# Loss after mini-batch   450: 0.152
# Loss after mini-batch   500: 0.161
# Loss after mini-batch   550: 0.161
# Loss after mini-batch   600: 0.150
# Loss after mini-batch   650: 0.130
# Loss after mini-batch   700: 0.156
# Loss after mini-batch   750: 0.150
# Loss after mini-batch   800: 0.156
# Loss after mini-batch   850: 0.154
# Loss after mini-batch   900: 0.134
# Loss after mini-batch   950: 0.140
# Loss after mini-batch  1000: 0.146
# Loss after mini-batch  1050: 0.142
# Loss after mini-batch  1100: 0.169
# ...
# Loss after mini-batch    50: 0.101
# Loss after mini-batch   100: 0.098
# Loss after mini-batch   150: 0.099
# Loss after mini-batch   200: 0.094
# Loss after mini-batch   250: 0.092
# Loss after mini-batch   300: 0.090
# Loss after mini-batch   350: 0.089
# Loss after mini-batch   400: 0.084
# Loss after mini-batch   450: 0.101
# Loss after mini-batch   500: 0.095
# Loss after mini-batch   550: 0.101
# Loss after mini-batch   600: 0.090
# Loss after mini-batch   650: 0.086
# Loss after mini-batch   700: 0.113
# Loss after mini-batch   750: 0.098
# Loss after mini-batch   800: 0.098
# Loss after mini-batch   850: 0.079
# Loss after mini-batch   900: 0.095
# Loss after mini-batch   950: 0.097
# Loss after mini-batch  1000: 0.114
# Loss after mini-batch  1050: 0.090
# Loss after mini-batch  1100: 0.107
# Loss after mini-batch  1150: 0.120
# Loss after mini-batch  1200: 0.082
# Loss after mini-batch  1250: 0.102
# Loss after mini-batch  1300: 0.104
# Loss after mini-batch  1350: 0.110
# Loss after mini-batch  1400: 0.096
# Loss after mini-batch  1450: 0.092
# Loss after mini-batch  1500: 0.098
# Loss after mini-batch  1550: 0.107
# Loss after mini-batch  1600: 0.106
# Loss after mini-batch  1650: 0.106
# Loss after mini-batch  1700: 0.098
# Loss after mini-batch  1750: 0.092
# Loss after mini-batch  1800: 0.089
# Loss after mini-batch  1850: 0.103
# Loss after mini-batch  1900: 0.105
# Loss after mini-batch  1950: 0.080
# Loss after mini-batch  2000: 0.094
# Loss after mini-batch  2050: 0.104
# Loss after mini-batch  2100: 0.100
# Loss after mini-batch  2150: 0.094
# Starting epoch 42
# Loss after mini-batch    50: 0.083
# Loss after mini-batch   100: 0.090
# Loss after mini-batch   150: 0.102
# Loss after mini-batch   200: 0.081
# Loss after mini-batch   250: 0.099
# Loss after mini-batch   300: 0.089
# Loss after mini-batch   350: 0.096
# Loss after mini-batch   400: 0.084
# Loss after mini-batch   450: 0.094
# Loss after mini-batch   500: 0.092
# Loss after mini-batch   550: 0.096
# Loss after mini-batch   600: 0.096
# Loss after mini-batch   650: 0.088
# Loss after mini-batch   700: 0.094
# Loss after mini-batch   750: 0.089
# Loss after mini-batch   800: 0.087
# Loss after mini-batch   850: 0.098
# Loss after mini-batch   900: 0.081
# Loss after mini-batch   950: 0.092
# Loss after mini-batch  1000: 0.097
# Loss after mini-batch  1050: 0.098
# Loss after mini-batch  1100: 0.107
# Loss after mini-batch  1150: 0.090
# Loss after mini-batch  1200: 0.101
# Loss after mini-batch  1250: 0.104
# Loss after mini-batch  1300: 0.110
# Loss after mini-batch  1350: 0.098
# Loss after mini-batch  1400: 0.094
# Loss after mini-batch  1450: 0.111
# Loss after mini-batch  1500: 0.117
# Loss after mini-batch  1550: 0.084
# Loss after mini-batch  1600: 0.097
# Loss after mini-batch  1650: 0.090
# Loss after mini-batch  1700: 0.108
# Loss after mini-batch  1750: 0.100
# Loss after mini-batch  1800: 0.098
# Loss after mini-batch  1850: 0.098
# Loss after mini-batch  1900: 0.098
# Loss after mini-batch  1950: 0.088
# Loss after mini-batch  2000: 0.108
# Loss after mini-batch  2050: 0.106
# Loss after mini-batch  2100: 0.097
# Loss after mini-batch  2150: 0.097
# Starting epoch 43
# Loss after mini-batch    50: 0.082
# Loss after mini-batch   100: 0.098
# Loss after mini-batch   150: 0.084
# Loss after mini-batch   200: 0.088
# Loss after mini-batch   250: 0.099
# Loss after mini-batch   300: 0.089
# Loss after mini-batch   350: 0.084
# Loss after mini-batch   400: 0.098
# Loss after mini-batch   450: 0.096
# Loss after mini-batch   500: 0.082
# Loss after mini-batch   550: 0.092
# Loss after mini-batch   600: 0.079
# Loss after mini-batch   650: 0.091
# Loss after mini-batch   700: 0.107
# Loss after mini-batch   750: 0.094
# Loss after mini-batch   800: 0.096
# Loss after mini-batch   850: 0.111
# Loss after mini-batch   900: 0.092
# Loss after mini-batch   950: 0.098
# Loss after mini-batch  1000: 0.093
# Loss after mini-batch  1050: 0.107
# Loss after mini-batch  1100: 0.098
# Loss after mini-batch  1150: 0.084
# Loss after mini-batch  1200: 0.094
# Loss after mini-batch  1250: 0.092
# Loss after mini-batch  1300: 0.101
# Loss after mini-batch  1350: 0.090
# Loss after mini-batch  1400: 0.099
# Loss after mini-batch  1450: 0.093
# Loss after mini-batch  1500: 0.089
# Loss after mini-batch  1550: 0.085
# Loss after mini-batch  1600: 0.095
# Loss after mini-batch  1650: 0.110
# Loss after mini-batch  1700: 0.100
# Loss after mini-batch  1750: 0.092
# Loss after mini-batch  1800: 0.109
# Loss after mini-batch  1850: 0.108
# Loss after mini-batch  1900: 0.105
# Loss after mini-batch  1950: 0.090
# Loss after mini-batch  2000: 0.094
# Loss after mini-batch  2050: 0.096
# Loss after mini-batch  2100: 0.104
# Loss after mini-batch  2150: 0.108
# Starting epoch 44
# Loss after mini-batch    50: 0.103
# Loss after mini-batch   100: 0.090
# Loss after mini-batch   150: 0.089
# Loss after mini-batch   200: 0.114
# Loss after mini-batch   250: 0.097
# Loss after mini-batch   300: 0.087
# Loss after mini-batch   350: 0.094
# Loss after mini-batch   400: 0.094
# Loss after mini-batch   450: 0.102
# Loss after mini-batch   500: 0.082
# Loss after mini-batch   550: 0.100
# Loss after mini-batch   600: 0.079
# Loss after mini-batch   650: 0.076
# Loss after mini-batch   700: 0.097
# Loss after mini-batch   750: 0.092
# Loss after mini-batch   800: 0.097
# Loss after mini-batch   850: 0.084
# Loss after mini-batch   900: 0.069
# Loss after mini-batch   950: 0.091
# Loss after mini-batch  1000: 0.089
# Loss after mini-batch  1050: 0.102
# Loss after mini-batch  1100: 0.080
# Loss after mini-batch  1150: 0.091
# Loss after mini-batch  1200: 0.111
# Loss after mini-batch  1250: 0.099
# Loss after mini-batch  1300: 0.086
# Loss after mini-batch  1350: 0.105
# Loss after mini-batch  1400: 0.077
# Loss after mini-batch  1450: 0.080
# Loss after mini-batch  1500: 0.087
# Loss after mini-batch  1550: 0.111
# Loss after mini-batch  1600: 0.086
# Loss after mini-batch  1650: 0.086
# Loss after mini-batch  1700: 0.095
# Loss after mini-batch  1750: 0.091
# Loss after mini-batch  1800: 0.101
# Loss after mini-batch  1850: 0.096
# Loss after mini-batch  1900: 0.099
# Loss after mini-batch  1950: 0.091
# Loss after mini-batch  2000: 0.103
# Loss after mini-batch  2050: 0.088
# Loss after mini-batch  2100: 0.095
# Loss after mini-batch  2150: 0.102
# Starting epoch 45
# Loss after mini-batch    50: 0.075
# Loss after mini-batch   100: 0.094
# Loss after mini-batch   150: 0.082
# Loss after mini-batch   200: 0.091
# Loss after mini-batch   250: 0.082
# Loss after mini-batch   300: 0.087
# Loss after mini-batch   350: 0.094
# Loss after mini-batch   400: 0.077
# Loss after mini-batch   450: 0.098
# Loss after mini-batch   500: 0.087
# Loss after mini-batch   550: 0.100
# Loss after mini-batch   600: 0.099
# Loss after mini-batch   650: 0.093
# Loss after mini-batch   700: 0.081
# Loss after mini-batch   750: 0.085
# Loss after mini-batch   800: 0.092
# Loss after mini-batch   850: 0.089
# Loss after mini-batch   900: 0.096
# Loss after mini-batch   950: 0.093
# Loss after mini-batch  1000: 0.093
# Loss after mini-batch  1050: 0.089
# Loss after mini-batch  1100: 0.084
# Loss after mini-batch  1150: 0.101
# Loss after mini-batch  1200: 0.094
# Loss after mini-batch  1250: 0.114
# Loss after mini-batch  1300: 0.096
# Loss after mini-batch  1350: 0.095
# Loss after mini-batch  1400: 0.104
# Loss after mini-batch  1450: 0.094
# Loss after mini-batch  1500: 0.094
# Loss after mini-batch  1550: 0.084
# Loss after mini-batch  1600: 0.100
# Loss after mini-batch  1650: 0.097
# Loss after mini-batch  1700: 0.095
# Loss after mini-batch  1750: 0.089
# Loss after mini-batch  1800: 0.078
# Loss after mini-batch  1850: 0.112
# Loss after mini-batch  1900: 0.088
# Loss after mini-batch  1950: 0.108
# Loss after mini-batch  2000: 0.114
# Loss after mini-batch  2050: 0.098
# Loss after mini-batch  2100: 0.110
# Loss after mini-batch  2150: 0.076
# Starting epoch 46
# Loss after mini-batch    50: 0.087
# Loss after mini-batch   100: 0.084
# Loss after mini-batch   150: 0.086
# Loss after mini-batch   200: 0.091
# Loss after mini-batch   250: 0.090
# Loss after mini-batch   300: 0.085
# Loss after mini-batch   350: 0.085
# Loss after mini-batch   400: 0.091
# Loss after mini-batch   450: 0.091
# Loss after mini-batch   500: 0.085
# Loss after mini-batch   550: 0.092
# Loss after mini-batch   600: 0.078
# Loss after mini-batch   650: 0.085
# Loss after mini-batch   700: 0.101
# Loss after mini-batch   750: 0.085
# Loss after mini-batch   800: 0.116
# Loss after mini-batch   850: 0.078
# Loss after mini-batch   900: 0.091
# Loss after mini-batch   950: 0.097
# Loss after mini-batch  1000: 0.078
# Loss after mini-batch  1050: 0.082
# Loss after mini-batch  1100: 0.096
# Loss after mini-batch  1150: 0.081
# Loss after mini-batch  1200: 0.084
# Loss after mini-batch  1250: 0.090
# Loss after mini-batch  1300: 0.082
# Loss after mini-batch  1350: 0.101
# Loss after mini-batch  1400: 0.092
# Loss after mini-batch  1450: 0.104
# Loss after mini-batch  1500: 0.080
# Loss after mini-batch  1550: 0.089
# Loss after mini-batch  1600: 0.082
# Loss after mini-batch  1650: 0.086
# Loss after mini-batch  1700: 0.107
# Loss after mini-batch  1750: 0.097
# Loss after mini-batch  1800: 0.090
# Loss after mini-batch  1850: 0.076
# Loss after mini-batch  1900: 0.091
# Loss after mini-batch  1950: 0.100
# Loss after mini-batch  2000: 0.075
# Loss after mini-batch  2050: 0.086
# Loss after mini-batch  2100: 0.088
# Loss after mini-batch  2150: 0.096
# Starting epoch 47
# Loss after mini-batch    50: 0.094
# Loss after mini-batch   100: 0.078
# Loss after mini-batch   150: 0.098
# Loss after mini-batch   200: 0.075
# Loss after mini-batch   250: 0.095
# Loss after mini-batch   300: 0.090
# Loss after mini-batch   350: 0.088
# Loss after mini-batch   400: 0.096
# Loss after mini-batch   450: 0.086
# Loss after mini-batch   500: 0.079
# Loss after mini-batch   550: 0.088
# Loss after mini-batch   600: 0.097
# Loss after mini-batch   650: 0.085
# Loss after mini-batch   700: 0.089
# Loss after mini-batch   750: 0.082
# Loss after mini-batch   800: 0.078
# Loss after mini-batch   850: 0.092
# Loss after mini-batch   900: 0.088
# Loss after mini-batch   950: 0.086
# Loss after mini-batch  1000: 0.100
# Loss after mini-batch  1050: 0.089
# Loss after mini-batch  1100: 0.099
# Loss after mini-batch  1150: 0.082
# Loss after mini-batch  1200: 0.086
# Loss after mini-batch  1250: 0.077
# Loss after mini-batch  1300: 0.100
# Loss after mini-batch  1350: 0.102
# Loss after mini-batch  1400: 0.076
# Loss after mini-batch  1450: 0.072
# Loss after mini-batch  1500: 0.092
# Loss after mini-batch  1550: 0.100
# Loss after mini-batch  1600: 0.080
# Loss after mini-batch  1650: 0.082
# Loss after mini-batch  1700: 0.094
# Loss after mini-batch  1750: 0.121
# Loss after mini-batch  1800: 0.078
# Loss after mini-batch  1850: 0.101
# Loss after mini-batch  1900: 0.095
# Loss after mini-batch  1950: 0.095
# Loss after mini-batch  2000: 0.090
# Loss after mini-batch  2050: 0.090
# Loss after mini-batch  2100: 0.104
# Loss after mini-batch  2150: 0.099
# Starting epoch 48
# Loss after mini-batch    50: 0.088
# Loss after mini-batch   100: 0.075
# Loss after mini-batch   150: 0.092
# Loss after mini-batch   200: 0.078
# Loss after mini-batch   250: 0.069
# Loss after mini-batch   300: 0.078
# Loss after mini-batch   350: 0.085
# Loss after mini-batch   400: 0.090
# Loss after mini-batch   450: 0.077
# Loss after mini-batch   500: 0.094
# Loss after mini-batch   550: 0.113
# Loss after mini-batch   600: 0.084
# Loss after mini-batch   650: 0.076
# Loss after mini-batch   700: 0.098
# Loss after mini-batch   750: 0.078
# Loss after mini-batch   800: 0.088
# Loss after mini-batch   850: 0.095
# Loss after mini-batch   900: 0.074
# Loss after mini-batch   950: 0.094
# Loss after mini-batch  1000: 0.095
# Loss after mini-batch  1050: 0.090
# Loss after mini-batch  1100: 0.078
# Loss after mini-batch  1150: 0.089
# Loss after mini-batch  1200: 0.099
# Loss after mini-batch  1250: 0.084
# Loss after mini-batch  1300: 0.095
# Loss after mini-batch  1350: 0.091
# Loss after mini-batch  1400: 0.079
# Loss after mini-batch  1450: 0.094
# Loss after mini-batch  1500: 0.082
# Loss after mini-batch  1550: 0.104
# Loss after mini-batch  1600: 0.098
# Loss after mini-batch  1650: 0.097
# Loss after mini-batch  1700: 0.090
# Loss after mini-batch  1750: 0.084
# Loss after mini-batch  1800: 0.080
# Loss after mini-batch  1850: 0.101
# Loss after mini-batch  1900: 0.087
# Loss after mini-batch  1950: 0.088
# Loss after mini-batch  2000: 0.094
# Loss after mini-batch  2050: 0.088
# Loss after mini-batch  2100: 0.095
# Loss after mini-batch  2150: 0.083
# Starting epoch 49
# Loss after mini-batch    50: 0.070
# Loss after mini-batch   100: 0.082
# Loss after mini-batch   150: 0.085
# Loss after mini-batch   200: 0.084
# Loss after mini-batch   250: 0.071
# Loss after mini-batch   300: 0.081
# Loss after mini-batch   350: 0.093
# Loss after mini-batch   400: 0.078
# Loss after mini-batch   450: 0.082
# Loss after mini-batch   500: 0.089
# Loss after mini-batch   550: 0.090
# Loss after mini-batch   600: 0.085
# Loss after mini-batch   650: 0.070
# Loss after mini-batch   700: 0.087
# Loss after mini-batch   750: 0.074
# Loss after mini-batch   800: 0.093
# Loss after mini-batch   850: 0.085
# Loss after mini-batch   900: 0.081
# Loss after mini-batch   950: 0.088
# Loss after mini-batch  1000: 0.098
# Loss after mini-batch  1050: 0.093
# Loss after mini-batch  1100: 0.085
# Loss after mini-batch  1150: 0.076
# Loss after mini-batch  1200: 0.089
# Loss after mini-batch  1250: 0.073
# Loss after mini-batch  1300: 0.084
# Loss after mini-batch  1350: 0.099
# Loss after mini-batch  1400: 0.089
# Loss after mini-batch  1450: 0.091
# Loss after mini-batch  1500: 0.105
# Loss after mini-batch  1550: 0.092
# Loss after mini-batch  1600: 0.103
# Loss after mini-batch  1650: 0.094
# Loss after mini-batch  1700: 0.089
# Loss after mini-batch  1750: 0.085
# Loss after mini-batch  1800: 0.093
# Loss after mini-batch  1850: 0.088
# Loss after mini-batch  1900: 0.095
# Loss after mini-batch  1950: 0.090
# Loss after mini-batch  2000: 0.094
# Loss after mini-batch  2050: 0.090
# Loss after mini-batch  2100: 0.101
# Loss after mini-batch  2150: 0.098
# Starting epoch 50
# Loss after mini-batch    50: 0.081
# Loss after mini-batch   100: 0.085
# Loss after mini-batch   150: 0.105
# Loss after mini-batch   200: 0.073
# Loss after mini-batch   250: 0.070
# Loss after mini-batch   300: 0.076
# Loss after mini-batch   350: 0.079
# Loss after mini-batch   400: 0.083
# Loss after mini-batch   450: 0.074
# Loss after mini-batch   500: 0.085
# Loss after mini-batch   550: 0.080
# Loss after mini-batch   600: 0.075
# Loss after mini-batch   650: 0.076
# Loss after mini-batch   700: 0.075
# Loss after mini-batch   750: 0.086
# Loss after mini-batch   800: 0.095
# Loss after mini-batch   850: 0.086
# Loss after mini-batch   900: 0.080
# Loss after mini-batch   950: 0.083
# Loss after mini-batch  1000: 0.112
# Loss after mini-batch  1050: 0.089
# Loss after mini-batch  1100: 0.083
# Loss after mini-batch  1150: 0.086
# Loss after mini-batch  1200: 0.080
# Loss after mini-batch  1250: 0.086
# Loss after mini-batch  1300: 0.076
# Loss after mini-batch  1350: 0.076
# Loss after mini-batch  1400: 0.072
# Loss after mini-batch  1450: 0.085
# Loss after mini-batch  1500: 0.089
# Loss after mini-batch  1550: 0.080
# Loss after mini-batch  1600: 0.083
# Loss after mini-batch  1650: 0.073
# Loss after mini-batch  1700: 0.085
# Loss after mini-batch  1750: 0.091
# Loss after mini-batch  1800: 0.082
# Loss after mini-batch  1850: 0.071
# Loss after mini-batch  1900: 0.084
# Loss after mini-batch  1950: 0.100
# Loss after mini-batch  2000: 0.101
# Loss after mini-batch  2050: 0.088
# Loss after mini-batch  2100: 0.098
# Loss after mini-batch  2150: 0.083
# Training process has finished. Saving trained model.
# Accuracy for fold 15: 94.3156320119671 %
# F1 score for fold 15: 94.31803266380686
# --------------------------------
# K-FOLD CROSS VALIDATION RESULTS FOR 16 FOLDS
# --------------------------------
# Fold 0: 94.60470085470085 %
# Fold 1: 94.79700854700855 %
# Fold 2: 94.90384615384616 %
# Fold 3: 94.86111111111111 %
# Fold 4: 94.46581196581197 %
# Fold 5: 94.72222222222223 %
# Fold 6: 94.97809595042206 %
# Fold 7: 94.45453574099797 %
# Fold 8: 94.86056202585746 %
# Fold 9: 95.04220536382093 %
# Fold 10: 94.43316593653168 %
# Fold 11: 94.75371300352602 %
# Fold 12: 95.2772732129501 %
# Fold 13: 94.81782241692488 %
# Fold 14: 95.03152046158777 %
# Fold 15: 94.3156320119671 %
# Average Accuracy: 94.76995168620543 %
# Average F1 score: 94.76746183553001 %

# %%
models = []
for i in range(16):
    state_dict = torch.load(f"model-fold-{i}_rs.pth")  # Load the state dictionary of each model
    model = bird_net  # Instantiate your model class
    model.load_state_dict(state_dict)  # Load the state dictionary into the model
    models.append(model)

class BirdNetEnsemble(nn.Module):
    def __init__(self, models):
        super(BirdNetEnsemble, self).__init__()
        self.models = models

    def forward(self, x):
        predictions = [model(x) for model in self.models]
        predictions = torch.stack(predictions)  # Shape: (num_models, batch_size, num_classes)
        majority_votes = torch.mode(predictions, dim=0).values  # Perform majority voting
        probs = F.softmax(majority_votes, dim=1)
        pred_class = torch.argmax(probs, dim=1)
        return pred_class

bird_torch_ensembled = BirdNetEnsemble(models)  
torch.save(bird_torch_ensembled.state_dict(), 'BirdTorchEnsembled')

# %%
def test_on_samples(bird, sample_idx):
  dataset_i = dataset_t[dataset_t[:,-1] == bird]
  sample = torch.tensor(dataset_i[sample_idx][0:-1], dtype=torch.float32)
  sample = sample.unsqueeze(0) 


  with torch.no_grad():
    bird_torch_ensembled.eval()
    pred = bird_torch_ensembled(sample.to(device))
  return pred



for i in range(0,7):
  for j in range(0, 30):
    print(test_on_samples(i, j))
  print('----------------------')
